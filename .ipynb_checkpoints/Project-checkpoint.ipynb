# %%
# %load_ext autoreload
# %autoreload 2
from src.data_collection import *
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Create setup:

# %%
import os
os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/clean", exist_ok=True)
os.makedirs("data/compressed", exist_ok=True)

# %% [markdown]
# # Data scraping from Wikipedia lists:

# %%
urls = [
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(0-9,_A-C)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(D-J)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(K-R)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(S-Z)",
"http://en.wikipedia.org/wiki/List_of_short_fiction_made_into_feature_films",
"https://en.wikipedia.org/wiki/List_of_children%27s_books_made_into_feature_films",
#"https://en.wikipedia.org/wiki/List_of_films_based_on_comics"
]
df = scrape_wikipedia_list(urls)
df.columns=['Book','author_book','Film',"Year_book", "Year_film"]

df # fix later
# Out:
#                                  Book         author_book  \
# 0                       The 25th Hour       David Benioff
# 1                         3 Assassins        Kōtarō Isaka
# 2                4.50 from Paddington     Agatha Christie
# 3                4.50 from Paddington     Agatha Christie
# 4                          58 Minutes        Walter Wager
# ...                               ...                 ...
# 5805                  Z for Zachariah   Robert C. O'Brien
# 5806                          Zathura  Chris Van Allsburg
# 5807  Zenon: Girl of the 21st Century      Marilyn Sadler
# 5808  Zenon: Girl of the 21st Century      Marilyn Sadler
# 5809  Zenon: Girl of the 21st Century      Marilyn Sadler
#
#                                  Film Year_book Year_film
# 0                           25th Hour      2001      2002
# 1                         Grasshopper      2004      2015
# 2                    Murder, She Said      1957      1961
# 3               Crime Is Our Business      1957      2008
# 4                          Die Hard 2      1987      1990
# ...                               ...       ...       ...
# 5805                  Z for Zachariah      1974      2015
# 5806                          Zathura      2002      2005
# 5807  Zenon: Girl of the 21st Century      1997      1999
# 5808                Zenon: The Zequel      1997      2001
# 5809                        Zenon: Z3      1997      2003
#
# [5810 rows x 5 columns]

# %%
r = tmdb_search_movie("zathura")
m = tmdb_get_movie_details(r["id"])
m
# Out:
# {'adult': False,
#  'backdrop_path': '/s9Bn7Mx4U9cWOR1WdFZjU1DTAkh.jpg',
#  'belongs_to_collection': None,
#  'budget': 65000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 12, 'name': 'Adventure'},
#   {'id': 10751, 'name': 'Family'}],
#  'homepage': 'https://www.sonypictures.com/movies/zathura',
#  'id': 6795,
#  'imdb_id': 'tt0406375',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Zathura: A Space Adventure',
#  'overview': 'After their father is called into work, two young boys, Walter and Danny, are left in the care of their teenage sister, Lisa, and told they must stay inside. Walter and Danny, who anticipate a boring day, are shocked when they begin playing Zathura, a space-themed board game, which they realize has mystical powers when their house is shot into space. With the help of an astronaut, the boys attempt to return home.',
#  'popularity': 4.5906,
#  'poster_path': '/gDb5BW2NLqZ9cvg9nyzkZVvmgze.jpg',
#  'production_companies': [{'id': 2550,
#    'logo_path': None,
#    'name': 'Teitler Film',
#    'origin_country': 'US'},
#   {'id': 11370,
#    'logo_path': None,
#    'name': 'Michael De Luca Productions',
#    'origin_country': 'US'},
#   {'id': 5,
#    'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png',
#    'name': 'Columbia Pictures',
#    'origin_country': 'US'},
#   {'id': 350,
#    'logo_path': '/bW7Ew27756PFKI3ucLFDIKEkFc0.png',
#    'name': 'Radar Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2005-11-06',
#  'revenue': 65079104,
#  'runtime': 101,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Adventure Is Waiting',
#  'title': 'Zathura: A Space Adventure',
#  'video': False,
#  'vote_average': 6.43,
#  'vote_count': 3442,
#  'credits': {'cast': [{'adult': False,
#     'gender': 2,
#     'id': 27972,
#     'known_for_department': 'Acting',
#     'name': 'Josh Hutcherson',
#     'original_name': 'Josh Hutcherson',
#     'popularity': 3.7934,
#     'profile_path': '/f0eosZ1Fx0VBUyspq8K2f8sUSBn.jpg',
#     'cast_id': 6,
#     'character': 'Walter Budwing',
#     'credit_id': '52fe4466c3a36847f80939e5',
#     'order': 0},
#    {'adult': False,
#     'gender': 2,
#     'id': 51297,
#     'known_for_department': 'Acting',
#     'name': 'Jonah Bobo',
#     'original_name': 'Jonah Bobo',
#     'popularity': 1.6257,
#     'profile_path': '/AnPqW5BW52X2nrAUcv9oQnK8xPu.jpg',
#     'cast_id': 5,
#     'character': 'Danny Budwing',
#     'credit_id': '52fe4466c3a36847f80939e1',
#     'order': 1},
#    {'adult': False,
#     'gender': 2,
#     'id': 51298,
#     'known_for_department': 'Acting',
#     'name': 'Dax Shepard',
#     'original_name': 'Dax Shepard',
#     'popularity': 2.6448,
#     'profile_path': '/aaUGRjfghjgysn5grVdm8kyYN4V.jpg',
#     'cast_id': 7,
#     'character': 'Astronaut',
#     'credit_id': '52fe4466c3a36847f80939e9',
#     'order': 2},
#    {'adult': False,
#     'gender': 1,
#     'id': 37917,
#     'known_for_department': 'Acting',
#     'name': 'Kristen Stewart',
#     'original_name': 'Kristen Stewart',
#     'popularity': 3.4065,
#     'profile_path': '/ryhCjTGqS6G6OprbR0qUEH355lA.jpg',
#     'cast_id': 23,
#     'character': 'Lisa Budwing',
#     'credit_id': '52fe4466c3a36847f8093a2f',
#     'order': 3},
#    {'adult': False,
#     'gender': 2,
#     'id': 504,
#     'known_for_department': 'Acting',
#     'name': 'Tim Robbins',
#     'original_name': 'Tim Robbins',
#     'popularity': 2.3713,
#     'profile_path': '/djLVFETFTvPyVUdrd7aLVykobof.jpg',
#     'cast_id': 9,
#     'character': 'Dad (Mr. Budwing)',
#     'credit_id': '52fe4466c3a36847f80939ed',
#     'order': 4},
#    {'adult': False,
#     'gender': 2,
#     'id': 7908,
#     'known_for_department': 'Acting',
#     'name': 'Frank Oz',
#     'original_name': 'Frank Oz',
#     'popularity': 1.3461,
#     'profile_path': '/mb2JbT8s6LIgaxj6QTph0NW1pmI.jpg',
#     'cast_id': 10,
#     'character': 'Robot (voice)',
#     'credit_id': '52fe4466c3a36847f80939f1',
#     'order': 5},
#    {'adult': False,
#     'gender': 2,
#     'id': 443770,
#     'known_for_department': 'Acting',
#     'name': 'John Alexander',
#     'original_name': 'John Alexander',
#     'popularity': 1.0429,
#     'profile_path': '/9YmbNIO0doeR9FoojgGia7VtpJF.jpg',
#     'cast_id': 24,
#     'character': 'Robot',
#     'credit_id': '52fe4466c3a36847f8093a33',
#     'order': 6},
#    {'adult': False,
#     'gender': 2,
#     'id': 51300,
#     'known_for_department': 'Acting',
#     'name': 'Derek Mears',
#     'original_name': 'Derek Mears',
#     'popularity': 2.1488,
#     'profile_path': '/2ckpSGUa4EDKWS1KMP0hLtFUWi.jpg',
#     'cast_id': 12,
#     'character': 'Lead Zorgon',
#     'credit_id': '52fe4466c3a36847f80939f5',
#     'order': 7},
#    {'adult': False,
#     'gender': 2,
#     'id': 51301,
#     'known_for_department': 'Acting',
#     'name': 'Douglas Tait',
#     'original_name': 'Douglas Tait',
#     'popularity': 1.1112,
#     'profile_path': '/srV2pY6rPyTpHGW5saOhdbRfcrv.jpg',
#     'cast_id': 13,
#     'character': 'Zorgon',
#     'credit_id': '52fe4466c3a36847f80939f9',
#     'order': 8},
#    {'adult': False,
#     'gender': 2,
#     'id': 51302,
#     'known_for_department': 'Crew',
#     'name': 'Joe Bucaro III',
#     'original_name': 'Joe Bucaro III',
#     'popularity': 0.7848,
#     'profile_path': '/gvJs1YQZRrSbkiSGAiCAugaXyzl.jpg',
#     'cast_id': 14,
#     'character': 'Zorgon',
#     'credit_id': '52fe4466c3a36847f80939fd',
#     'order': 9},
#    {'adult': False,
#     'gender': 2,
#     'id': 51303,
#     'known_for_department': 'Acting',
#     'name': 'Jeff Wolfe',
#     'original_name': 'Jeff Wolfe',
#     'popularity': 0.8022,
#     'profile_path': '/mrbVMbf2IOKP9hzxH9rBZk8Vyp6.jpg',
#     'cast_id': 15,
#     'character': 'Zorgon',
#     'credit_id': '52fe4466c3a36847f8093a01',
#     'order': 10}],
#   'crew': [{'adult': False,
#     'gender': 2,
#     'id': 15277,
#     'known_for_department': 'Acting',
#     'name': 'Jon Favreau',
#     'original_name': 'Jon Favreau',
#     'popularity': 3.9328,
#     'profile_path': '/tnx7iMVydPQXGOoLsxXl84PXtbA.jpg',
#     'credit_id': '52fe4466c3a36847f80939cb',
#     'department': 'Directing',
#     'job': 'Director'},
#    {'adult': False,
#     'gender': 2,
#     'id': 508,
#     'known_for_department': 'Writing',
#     'name': 'David Koepp',
#     'original_name': 'David Koepp',
#     'popularity': 1.2779,
#     'profile_path': '/is3t4k8OMX0KNCD3EilDWOucYZG.jpg',
#     'credit_id': '52fe4466c3a36847f80939d7',
#     'department': 'Writing',
#     'job': 'Screenplay'},
#    {'adult': False,
#     'gender': 2,
#     'id': 51296,
#     'known_for_department': 'Writing',
#     'name': 'John Kamps',
#     'original_name': 'John Kamps',
#     'popularity': 0.8137,
#     'profile_path': '/diMLbG4uCdaLgWuZhU6MpbpIir0.jpg',
#     'credit_id': '52fe4466c3a36847f80939dd',
#     'department': 'Writing',
#     'job': 'Screenplay'},
#    {'adult': False,
#     'gender': 2,
#     'id': 4767,
#     'known_for_department': 'Production',
#     'name': 'Michael De Luca',
#     'original_name': 'Michael De Luca',
#     'popularity': 0.7723,
#     'profile_path': '/i87R2uZafgOmFdbT7PgCBXjsL5s.jpg',
#     'credit_id': '52fe4466c3a36847f8093a07',
#     'department': 'Production',
#     'job': 'Producer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 9184,
#     'known_for_department': 'Production',
#     'name': 'Scott Kroopf',
#     'original_name': 'Scott Kroopf',
#     'popularity': 0.3314,
#     'profile_path': None,
#     'credit_id': '52fe4466c3a36847f8093a0d',
#     'department': 'Production',
#     'job': 'Producer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 42357,
#     'known_for_department': 'Production',
#     'name': 'William Teitler',
#     'original_name': 'William Teitler',
#     'popularity': 0.6584,
#     'profile_path': None,
#     'credit_id': '52fe4466c3a36847f8093a13',
#     'department': 'Production',
#     'job': 'Producer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 4500,
#     'known_for_department': 'Sound',
#     'name': 'John Debney',
#     'original_name': 'John Debney',
#     'popularity': 0.6472,
#     'profile_path': '/iUwBpunUEdknzkRpgAyodwIEh4n.jpg',
#     'credit_id': '52fe4466c3a36847f8093a19',
#     'department': 'Sound',
#     'job': 'Original Music Composer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 3113,
#     'known_for_department': 'Camera',
#     'name': 'Guillermo Navarro',
#     'original_name': 'Guillermo Navarro',
#     'popularity': 0.1926,
#     'profile_path': '/nu89CBBBTaCD8VQoBhoXWNef8Yo.jpg',
#     'credit_id': '52fe4466c3a36847f8093a1f',
#     'department': 'Camera',
#     'job': 'Director of Photography'},
#    {'adult': False,
#     'gender': 1,
#     'id': 2952,
#     'known_for_department': 'Production',
#     'name': 'Avy Kaufman',
#     'original_name': 'Avy Kaufman',
#     'popularity': 0.5995,
#     'profile_path': '/9hh0HIAmLgPqMTn1keJvh1MF1DR.jpg',
#     'credit_id': '52fe4466c3a36847f8093a25',
#     'department': 'Production',
#     'job': 'Casting'},
#    {'adult': False,
#     'gender': 2,
#     'id': 11455,
#     'known_for_department': 'Editing',
#     'name': 'Dan Lebental',
#     'original_name': 'Dan Lebental',
#     'popularity': 0.2622,
#     'profile_path': '/8OyGl8GpIhcXRDL6BZTNQ8Hwljh.jpg',
#     'credit_id': '52fe4466c3a36847f8093a2b',
#     'department': 'Editing',
#     'job': 'Editor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 42356,
#     'known_for_department': 'Writing',
#     'name': 'Chris Van Allsburg',
#     'original_name': 'Chris Van Allsburg',
#     'popularity': 0.1451,
#     'profile_path': '/rQz9ZksXG5bmhjgulEk5jYaLwi.jpg',
#     'credit_id': '61177c71006b010046a471ed',
#     'department': 'Writing',
#     'job': 'Book'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1694504,
#     'known_for_department': 'Crew',
#     'name': 'Michelle Sebek',
#     'original_name': 'Michelle Sebek',
#     'popularity': 0.2438,
#     'profile_path': None,
#     'credit_id': '61177d853a99370071549fa0',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 3197316,
#     'known_for_department': 'Crew',
#     'name': 'Logan Brown',
#     'original_name': 'Logan Brown',
#     'popularity': 0.0495,
#     'profile_path': None,
#     'credit_id': '61177e24cee481005c8264f8',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1535124,
#     'known_for_department': 'Crew',
#     'name': 'Michael Runyard',
#     'original_name': 'Michael Runyard',
#     'popularity': 0.3604,
#     'profile_path': '/45OfE6u2HFb2vsZDgSIwSMX9IjN.jpg',
#     'credit_id': '61177e5887f3f2004546907a',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1209705,
#     'known_for_department': 'Crew',
#     'name': 'Reid Harper',
#     'original_name': 'Reid Harper',
#     'popularity': 0.9836,
#     'profile_path': None,
#     'credit_id': '61177ecfcee481002e29c5fb',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1767311,
#     'known_for_department': 'Crew',
#     'name': 'Shawn Kautz',
#     'original_name': 'Shawn Kautz',
#     'popularity': 0.1588,
#     'profile_path': None,
#     'credit_id': '61177f02151c5c002c7914a6',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1393339,
#     'known_for_department': 'Crew',
#     'name': 'Mike Justus',
#     'original_name': 'Mike Justus',
#     'popularity': 0.7522,
#     'profile_path': '/uHMGw78N0lZsZVOh9lgDIQERbPq.jpg',
#     'credit_id': '61177f492e0697005d97c312',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1866579,
#     'known_for_department': 'Crew',
#     'name': 'Tad Griffith',
#     'original_name': 'Tad Griffith',
#     'popularity': 0.3358,
#     'profile_path': '/izB74udztAJk6qbQSaks8co2Pv2.jpg',
#     'credit_id': '6117800687f3f2005cc170bf',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 18889,
#     'known_for_department': 'Crew',
#     'name': 'Mic Rodgers',
#     'original_name': 'Mic Rodgers',
#     'popularity': 0.5712,
#     'profile_path': '/zGhWhiTfzeSzfKt9kK4Bk6ZS0xn.jpg',
#     'credit_id': '6117801b151c5c00732a64a0',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 200402,
#     'known_for_department': 'Crew',
#     'name': 'Tim Trella',
#     'original_name': 'Tim Trella',
#     'popularity': 1.5219,
#     'profile_path': '/bzgr1RT7gmO75s3b2QGOfEcBJff.jpg',
#     'credit_id': '61178076006b010046a4767c',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 113981,
#     'known_for_department': 'Directing',
#     'name': 'Bruce Franklin',
#     'original_name': 'Bruce Franklin',
#     'popularity': 0.249,
#     'profile_path': None,
#     'credit_id': '6117811587f3f2007561d4ef',
#     'department': 'Directing',
#     'job': 'First Assistant Director'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1804880,
#     'known_for_department': 'Directing',
#     'name': 'Conte Mark Matal',
#     'original_name': 'Conte Mark Matal',
#     'popularity': 0.0739,
#     'profile_path': None,
#     'credit_id': '611782150f0da5005f4e7be9',
#     'department': 'Directing',
#     'job': 'Second Assistant Director'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1881574,
#     'known_for_department': 'Visual Effects',
#     'name': 'Daniel J. Lombardo',
#     'original_name': 'Daniel J. Lombardo',
#     'popularity': 0.0773,
#     'profile_path': None,
#     'credit_id': '61178299310325007e0fc9b9',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Producer'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1386923,
#     'known_for_department': 'Directing',
#     'name': 'Alicia Accardo',
#     'original_name': 'Alicia Accardo',
#     'popularity': 1.5101,
#     'profile_path': None,
#     'credit_id': '6117830b3a9937007154a46d',
#     'department': 'Directing',
#     'job': 'Script Supervisor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1550778,
#     'known_for_department': 'Camera',
#     'name': 'Harry K. Garvin',
#     'original_name': 'Harry K. Garvin',
#     'popularity': 0.1535,
#     'profile_path': None,
#     'credit_id': '6117834b2e069700734aec2c',
#     'department': 'Camera',
#     'job': '"A" Camera Operator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1550778,
#     'known_for_department': 'Camera',
#     'name': 'Harry K. Garvin',
#     'original_name': 'Harry K. Garvin',
#     'popularity': 0.1535,
#     'profile_path': None,
#     'credit_id': '61178354cee481002e29ca33',
#     'department': 'Camera',
#     'job': 'Steadicam Operator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1273377,
#     'known_for_department': 'Camera',
#     'name': 'Leo J. Napolitano',
#     'original_name': 'Leo J. Napolitano',
#     'popularity': 0.6207,
#     'profile_path': None,
#     'credit_id': '61178404151c5c00461039aa',
#     'department': 'Camera',
#     'job': '"B" Camera Operator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1540872,
#     'known_for_department': 'Camera',
#     'name': 'Timothy James Kane',
#     'original_name': 'Timothy James Kane',
#     'popularity': 0.4977,
#     'profile_path': None,
#     'credit_id': '61178464258823005ebc396a',
#     'department': 'Camera',
#     'job': 'First Assistant "A" Camera'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2266374,
#     'known_for_department': 'Camera',
#     'name': 'Tony Muller',
#     'original_name': 'Tony Muller',
#     'popularity': 0.0659,
#     'profile_path': None,
#     'credit_id': '611784d587f3f2005cc174b8',
#     'department': 'Camera',
#     'job': 'Second Assistant "A" Camera'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1555643,
#     'known_for_department': 'Camera',
#     'name': 'Matthew E. Alper',
#     'original_name': 'Matthew E. Alper',
#     'popularity': 0.6193,
#     'profile_path': None,
#     'credit_id': '6117853f2e0697005d97c7bd',
#     'department': 'Camera',
#     'job': 'First Assistant "B" Camera'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1558206,
#     'known_for_department': 'Camera',
#     'name': 'Matthew Haskins',
#     'original_name': 'Matthew Haskins',
#     'popularity': 0.3752,
#     'profile_path': None,
#     'credit_id': '611785862e069700458fca68',
#     'department': 'Camera',
#     'job': 'Second Assistant "B" Camera'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1477790,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Lori Stilson',
#     'original_name': 'Lori Stilson',
#     'popularity': 0.0946,
#     'profile_path': None,
#     'credit_id': '611786be3103250046e5c924',
#     'department': 'Costume & Make-Up',
#     'job': 'Costumer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1404746,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Faye Sevilla',
#     'original_name': 'Faye Sevilla',
#     'popularity': 0.0982,
#     'profile_path': None,
#     'credit_id': '611786d3006b01002f22943a',
#     'department': 'Costume & Make-Up',
#     'job': 'Costumer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1708344,
#     'known_for_department': 'Camera',
#     'name': 'Rick Stribling',
#     'original_name': 'Rick Stribling',
#     'popularity': 1.0037,
#     'profile_path': None,
#     'credit_id': '61178ba6151c5c0046103ea0',
#     'department': 'Camera',
#     'job': 'Key Grip'},
#    {'adult': False,
#     'gender': 2,
#     'id': 3136625,
#     'known_for_department': 'Camera',
#     'name': 'Matthew Devitt',
#     'original_name': 'Matthew Devitt',
#     'popularity': 0.0482,
#     'profile_path': None,
#     'credit_id': '61178bf5e54d5d0074df5953',
#     'department': 'Camera',
#     'job': 'Best Boy Grip'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1547309,
#     'known_for_department': 'Sound',
#     'name': 'Mark Ulano',
#     'original_name': 'Mark Ulano',
#     'popularity': 0.2983,
#     'profile_path': '/b1NgERFBk7nuLkc4PD3cpmf6JWM.jpg',
#     'credit_id': '61178c7d87f3f2005cc17ad5',
#     'department': 'Sound',
#     'job': 'Production Sound Mixer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1339447,
#     'known_for_department': 'Sound',
#     'name': 'Tom Hartig',
#     'original_name': 'Tom Hartig',
#     'popularity': 0.8941,
#     'profile_path': None,
#     'credit_id': '61178cabcee48100458e1feb',
#     'department': 'Sound',
#     'job': 'Boom Operator'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1550830,
#     'known_for_department': 'Crew',
#     'name': 'Donald Frazee',
#     'original_name': 'Donald Frazee',
#     'popularity': 0.1112,
#     'profile_path': None,
#     'credit_id': '61178d7c2e069700458fd0ab',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2757252,
#     'known_for_department': 'Crew',
#     'name': 'Robert Harman',
#     'original_name': 'Robert Harman',
#     'popularity': 0.0831,
#     'profile_path': None,
#     'credit_id': '61178db3e54d5d0046c51b55',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1411266,
#     'known_for_department': 'Crew',
#     'name': 'Richard O. Helmer',
#     'original_name': 'Richard O. Helmer',
#     'popularity': 0.2004,
#     'profile_path': None,
#     'credit_id': '61178eb22e069700734af509',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 0,
#     'id': 3197378,
#     'known_for_department': 'Crew',
#     'name': 'Edward Kennedy',
#     'original_name': 'Edward Kennedy',
#     'popularity': 0.0214,
#     'profile_path': None,
#     'credit_id': '61178f7287f3f20045469d44',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2219853,
#     'known_for_department': 'Crew',
#     'name': 'William Lee',
#     'original_name': 'William Lee',
#     'popularity': 0.1287,
#     'profile_path': None,
#     'credit_id': '61178fe1006b010046a4846b',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2945272,
#     'known_for_department': 'Crew',
#     'name': 'Louis Lindwall',
#     'original_name': 'Louis Lindwall',
#     'popularity': 0.0962,
#     'profile_path': None,
#     'credit_id': '61179047310325005e5c5ebe',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2150316,
#     'known_for_department': 'Crew',
#     'name': 'Jeffrey Machit',
#     'original_name': 'Jeffrey Machit',
#     'popularity': 0.0546,
#     'profile_path': None,
#     'credit_id': '6117906c0f0da50030c7d139',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2150321,
#     'known_for_department': 'Crew',
#     'name': 'Paul Sabourin',
#     'original_name': 'Paul Sabourin',
#     'popularity': 0.0559,
#     'profile_path': None,
#     'credit_id': '61179101e54d5d0046c51e62',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2150334,
#     'known_for_department': 'Crew',
#     'name': 'Harold Selig',
#     'original_name': 'Harold Selig',
#     'popularity': 0.114,
#     'profile_path': None,
#     'credit_id': '6117914a87f3f2002c2ca95c',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1638721,
#     'known_for_department': 'Production',
#     'name': 'Kenneth Hunter',
#     'original_name': 'Kenneth Hunter',
#     'popularity': 0.0759,
#     'profile_path': None,
#     'credit_id': '6117920c310325007e0fd6b7',
#     'department': 'Production',
#     'job': 'Location Manager'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1573618,
#     'known_for_department': 'Production',
#     'name': 'Sheilah Sullivan',
#     'original_name': 'Sheilah Sullivan',
#     'popularity': 0.0614,
#     'profile_path': None,
#     'credit_id': '611792cccee481005c827791',
#     'department': 'Production',
#     'job': 'Production Accountant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1761290,
#     'known_for_department': 'Production',
#     'name': 'Ross Jensen',
#     'original_name': 'Ross Jensen',
#     'popularity': 0.1003,
#     'profile_path': None,
#     'credit_id': '61179306310325005e5c60d0',
#     'department': 'Production',
#     'job': 'Assistant Accountant'},
#    {'adult': False,
#     'gender': 2,
#     'id': 13304,
#     'known_for_department': 'Art',
#     'name': 'J. Michael Riva',
#     'original_name': 'J. Michael Riva',
#     'popularity': 0.8238,
#     'profile_path': '/54ds2S5EdGOG8ynqQyYm344vGib.jpg',
#     'credit_id': '5566cfc0c3a368174600110e',
#     'department': 'Art',
#     'job': 'Production Design'},
#    {'adult': False,
#     'gender': 2,
#     'id': 14350,
#     'known_for_department': 'Art',
#     'name': 'Richard F. Mays',
#     'original_name': 'Richard F. Mays',
#     'popularity': 0.1694,
#     'profile_path': None,
#     'credit_id': '5566cfed925141478f0012fd',
#     'department': 'Art',
#     'job': 'Art Direction'},
#    {'adult': False,
#     'gender': 1,
#     'id': 14348,
#     'known_for_department': 'Art',
#     'name': 'Lauri Gaffin',
#     'original_name': 'Lauri Gaffin',
#     'popularity': 0.2485,
#     'profile_path': None,
#     'credit_id': '5566d005925141478d001265',
#     'department': 'Art',
#     'job': 'Set Decoration'},
#    {'adult': False,
#     'gender': 1,
#     'id': 9551,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Laura Jean Shannon',
#     'original_name': 'Laura Jean Shannon',
#     'popularity': 0.2013,
#     'profile_path': '/e7Cmmphpmw5SBwg5ypCY8zsI77o.jpg',
#     'credit_id': '5566d01dc3a36817490012d0',
#     'department': 'Costume & Make-Up',
#     'job': 'Costume Design'},
#    {'adult': False,
#     'gender': 0,
#     'id': 117409,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Melanie Hughes',
#     'original_name': 'Melanie Hughes',
#     'popularity': 0.2109,
#     'profile_path': None,
#     'credit_id': '5566d0c0c3a368174b00111c',
#     'department': 'Costume & Make-Up',
#     'job': 'Makeup Department Head'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1190241,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Pat Welch',
#     'original_name': 'Pat Welch',
#     'popularity': 0.083,
#     'profile_path': None,
#     'credit_id': '5566d11692514147810012fd',
#     'department': 'Costume & Make-Up',
#     'job': 'Costume Supervisor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1471304,
#     'known_for_department': 'Crew',
#     'name': 'Paulette Dauber',
#     'original_name': 'Paulette Dauber',
#     'popularity': 0.0905,
#     'profile_path': None,
#     'credit_id': '5566d134925141477b0011c2',
#     'department': 'Crew',
#     'job': 'Unit Publicist'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1582764,
#     'known_for_department': 'Crew',
#     'name': 'Lisa Hoyle',
#     'original_name': 'Lisa Hoyle',
#     'popularity': 0.3295,
#     'profile_path': '/t7WFzuZ3GhpIldoFBWpgYatBHaO.jpg',
#     'credit_id': '65976b9f5907de117f63bfdb',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 14349,
#     'known_for_department': 'Art',
#     'name': 'David F. Klassen',
#     'original_name': 'David F. Klassen',
#     'popularity': 0.287,
#     'profile_path': None,
#     'credit_id': '570ab8409251417da700094f',
#     'department': 'Art',
#     'job': 'Supervising Art Director'},
#    {'adult': False,
#     'gender': 2,
#     'id': 68016,
#     'known_for_department': 'Sound',
#     'name': 'Kevin Kaska',
#     'original_name': 'Kevin Kaska',
#     'popularity': 0.3117,
#     'profile_path': '/azlSu8Sz9QGeK3xgQS9p3ZvR9q9.jpg',
#     'credit_id': '579d0f5ec3a36837ea00140e',
#     'department': 'Sound',
#     'job': 'Orchestrator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1558821,
#     'known_for_department': 'Sound',
#     'name': 'Mike Watts',
#     'original_name': 'Mike Watts',
#     'popularity': 0.1722,
#     'profile_path': None,
#     'credit_id': '5acab8130e0a26320a005adf',
#     'department': 'Sound',
#     'job': 'Orchestrator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 146352,
#     'known_for_department': 'Crew',
#     'name': 'Bob Brown',
#     'original_name': 'Bob Brown',
#     'popularity': 0.3296,
#     'profile_path': None,
#     'credit_id': '6482973699259c00ff0d833b',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1288830,
#     'known_for_department': 'Crew',
#     'name': 'Crystal Dalman',
#     'original_name': 'Crystal Dalman',
#     'popularity': 0.1532,
#     'profile_path': '/3xapSBLyiaVfpLPBRoxRXOZ9HfO.jpg',
#     'credit_id': '6485e53dbf31f250569c040c',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 4568530,
#     'known_for_department': 'Sound',
#     'name': 'Robert Fernandez',
#     'original_name': 'Robert Fernandez',
#     'popularity': 0.1486,
#     'profile_path': None,
#     'credit_id': '6696a49448178e1a007b8f41',
#     'department': 'Sound',
#     'job': 'Scoring Mixer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 12708,
#     'known_for_department': 'Acting',
#     'name': 'Peter Billingsley',
#     'original_name': 'Peter Billingsley',
#     'popularity': 0.94,
#     'profile_path': '/mgGquIo2diWHkRVbjRVULnMA46x.jpg',
#     'credit_id': '5b7048bc925141404f149620',
#     'department': 'Production',
#     'job': 'Co-Producer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 57027,
#     'known_for_department': 'Production',
#     'name': "Louis D'Esposito",
#     'original_name': "Louis D'Esposito",
#     'popularity': 1.225,
#     'profile_path': '/mPy6hxHrHoEOWdljLyZM6DNBSPn.jpg',
#     'credit_id': '5b7048e8c3a368189d1676bb',
#     'department': 'Production',
#     'job': 'Executive Producer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 9196,
#     'known_for_department': 'Production',
#     'name': 'Ted Field',
#     'original_name': 'Ted Field',
#     'popularity': 0.7628,
#     'profile_path': '/vy5tPqEHBpD02jsZeTdjaeEN1D7.jpg',
#     'credit_id': '5b7049170e0a267eeb18d2d4',
#     'department': 'Production',
#     'job': 'Executive Producer'},
#    {'adult': False,
#     'gender': 1,
#     'id': 2103723,
#     'known_for_department': 'Art',
#     'name': 'Rebecca Young',
#     'original_name': 'Rebecca Young',
#     'popularity': 0.0943,
#     'profile_path': None,
#     'credit_id': '5b707eff0e0a267eed18b4c6',
#     'department': 'Art',
#     'job': 'Art Department Coordinator'},
#    {'adult': False,
#     'gender': 1,
#     'id': 83080,
#     'known_for_department': 'Art',
#     'name': 'Wendy Riva',
#     'original_name': 'Wendy Riva',
#     'popularity': 0.4772,
#     'profile_path': None,
#     'credit_id': '5b707f0e925141404f14d6b5',
#     'department': 'Art',
#     'job': 'Assistant Art Director'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1404357,
#     'known_for_department': 'Art',
#     'name': 'Constantine Sekeris',
#     'original_name': 'Constantine Sekeris',
#     'popularity': 0.1179,
#     'profile_path': None,
#     'credit_id': '5b707f53925141406a17a950',
#     'department': 'Art',
#     'job': 'Conceptual Design'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1435578,
#     'known_for_department': 'Art',
#     'name': 'Walt Hadfield',
#     'original_name': 'Walt Hadfield',
#     'popularity': 0.0963,
#     'profile_path': None,
#     'credit_id': '5b707f75c3a36853750e6193',
#     'department': 'Art',
#     'job': 'Construction Coordinator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1643717,
#     'known_for_department': 'Art',
#     'name': 'Anthony Carlino',
#     'original_name': 'Anthony Carlino',
#     'popularity': 0.1336,
#     'profile_path': None,
#     'credit_id': '5b707f8e0e0a267ef81879ba',
#     'department': 'Art',
#     'job': 'Leadman'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2058969,
#     'known_for_department': 'Art',
#     'name': 'Maret Wicken',
#     'original_name': 'Maret Wicken',
#     'popularity': 0.0518,
#     'profile_path': None,
#     'credit_id': '5b707f9fc3a3681888177a12',
#     'department': 'Art',
#     'job': 'Painter'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2105670,
#     'known_for_department': 'Art',
#     'name': 'Phil Saunders',
#     'original_name': 'Phil Saunders',
#     'popularity': 0.1472,
#     'profile_path': None,
#     'credit_id': '5b707fb30e0a267ef1181662',
#     'department': 'Art',
#     'job': 'Production Illustrator'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105671,
#     'known_for_department': 'Art',
#     'name': 'Guy A. Mussori',
#     'original_name': 'Guy A. Mussori',
#     'popularity': 0.0143,
#     'profile_path': None,
#     'credit_id': '5b707fd60e0a267ef8187a4f',
#     'department': 'Art',
#     'job': 'Props'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1389610,
#     'known_for_department': 'Art',
#     'name': 'Peter Davidson',
#     'original_name': 'Peter Davidson',
#     'popularity': 0.0431,
#     'profile_path': None,
#     'credit_id': '5b70802f0e0a267ee718be7b',
#     'department': 'Art',
#     'job': 'Set Designer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1701724,
#     'known_for_department': 'Art',
#     'name': 'Andrew P. Flores',
#     'original_name': 'Andrew P. Flores',
#     'popularity': 0.1289,
#     'profile_path': None,
#     'credit_id': '5b7080b4c3a3681888177c40',
#     'department': 'Art',
#     'job': 'Standby Painter'},
#    {'adult': False,
#     'gender': 0,
#     'id': 239788,
#     'known_for_department': 'Camera',
#     'name': 'Charles Schner',
#     'original_name': 'Charles Schner',
#     'popularity': 0.1072,
#     'profile_path': None,
#     'credit_id': '5b7080c7c3a368188f17e970',
#     'department': 'Camera',
#     'job': 'Additional Camera'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105674,
#     'known_for_department': 'Camera',
#     'name': "Roberto 'Tito' Blasini",
#     'original_name': "Roberto 'Tito' Blasini",
#     'popularity': 0.0759,
#     'profile_path': None,
#     'credit_id': '5b7080ddc3a36818941c198a',
#     'department': 'Camera',
#     'job': 'Camera Operator'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1463768,
#     'known_for_department': 'Camera',
#     'name': 'Jason Talbert',
#     'original_name': 'Jason Talbert',
#     'popularity': 0.0846,
#     'profile_path': None,
#     'credit_id': '5b7080fe0e0a267eed18b8bf',
#     'department': 'Camera',
#     'job': 'Grip'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1172443,
#     'known_for_department': 'Camera',
#     'name': 'Merrick Morton',
#     'original_name': 'Merrick Morton',
#     'popularity': 0.1418,
#     'profile_path': None,
#     'credit_id': '5b70811c0e0a267ef118197b',
#     'department': 'Camera',
#     'job': 'Still Photographer'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1423983,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Rebecca Gregg',
#     'original_name': 'Rebecca Gregg',
#     'popularity': 0.107,
#     'profile_path': None,
#     'credit_id': '5b708134925141405614d20f',
#     'department': 'Costume & Make-Up',
#     'job': 'Assistant Costume Designer'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1471302,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Roxanne Wightman',
#     'original_name': 'Roxanne Wightman',
#     'popularity': 0.1201,
#     'profile_path': None,
#     'credit_id': '5b708157c3a368188f17ea62',
#     'department': 'Costume & Make-Up',
#     'job': 'Hair Department Head'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1408293,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Linda Flowers',
#     'original_name': 'Linda Flowers',
#     'popularity': 0.1892,
#     'profile_path': '/sC9of3RKFQ3RYNQMeX1SbJI0dBe.jpg',
#     'credit_id': '5b7081949251410341082a64',
#     'department': 'Costume & Make-Up',
#     'job': 'Key Hair Stylist'},
#    {'adult': False,
#     'gender': 0,
#     'id': 134564,
#     'known_for_department': 'Costume & Make-Up',
#     'name': 'Amy L. Disarro',
#     'original_name': 'Amy L. Disarro',
#     'popularity': 1.1378,
#     'profile_path': None,
#     'credit_id': '5b7081af0e0a267eed18b9c3',
#     'department': 'Costume & Make-Up',
#     'job': 'Key Makeup Artist'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1552998,
#     'known_for_department': 'Crew',
#     'name': 'Raymond Bulinski',
#     'original_name': 'Raymond Bulinski',
#     'popularity': 0.1583,
#     'profile_path': None,
#     'credit_id': '5b7081fe9251410341082b06',
#     'department': 'Crew',
#     'job': 'Craft Service'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1463846,
#     'known_for_department': 'Crew',
#     'name': 'John F. Teeple',
#     'original_name': 'John F. Teeple',
#     'popularity': 0.0889,
#     'profile_path': None,
#     'credit_id': '5b70821d0e0a267eeb192890',
#     'department': 'Crew',
#     'job': 'Driver'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1600624,
#     'known_for_department': 'Visual Effects',
#     'name': 'Shane Mahan',
#     'original_name': 'Shane Mahan',
#     'popularity': 0.2062,
#     'profile_path': None,
#     'credit_id': '5b7082389251414054164105',
#     'department': 'Crew',
#     'job': 'Makeup Effects'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105677,
#     'known_for_department': 'Crew',
#     'name': 'Kelly Birrer',
#     'original_name': 'Kelly Birrer',
#     'popularity': 0.0214,
#     'profile_path': None,
#     'credit_id': '5b7082570e0a267ef4180c0e',
#     'department': 'Crew',
#     'job': 'Propmaker'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105678,
#     'known_for_department': 'Crew',
#     'name': 'Scott Johnson',
#     'original_name': 'Scott Johnson',
#     'popularity': 0.0143,
#     'profile_path': None,
#     'credit_id': '5b7082b50e0a267ef4180ccb',
#     'department': 'Crew',
#     'job': 'Set Production Assistant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1684997,
#     'known_for_department': 'Crew',
#     'name': 'Cottalango Loorthu',
#     'original_name': 'Cottalango Loorthu',
#     'popularity': 0.0532,
#     'profile_path': None,
#     'credit_id': '5b7082dc0e0a267ef617d752',
#     'department': 'Crew',
#     'job': 'Software Engineer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2105679,
#     'known_for_department': 'Crew',
#     'name': 'David R. Maier',
#     'original_name': 'David R. Maier',
#     'popularity': 0.0497,
#     'profile_path': None,
#     'credit_id': '5b7082ebc3a36853750e67f4',
#     'department': 'Crew',
#     'job': 'Stand In'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1339453,
#     'known_for_department': 'Crew',
#     'name': 'Thomas Robinson Harper',
#     'original_name': 'Thomas Robinson Harper',
#     'popularity': 0.3264,
#     'profile_path': '/xPFdDSXceVebYdcYOKpkTpncWoC.jpg',
#     'credit_id': '5b70831dc3a368188817807f',
#     'department': 'Crew',
#     'job': 'Stunt Coordinator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2105681,
#     'known_for_department': 'Crew',
#     'name': 'Mark Brooks',
#     'original_name': 'Mark Brooks',
#     'popularity': 0.0474,
#     'profile_path': None,
#     'credit_id': '5b7083370e0a267ef1181d63',
#     'department': 'Crew',
#     'job': 'Stunts'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1602872,
#     'known_for_department': 'Crew',
#     'name': 'Dan Henley',
#     'original_name': 'Dan Henley',
#     'popularity': 0.1013,
#     'profile_path': None,
#     'credit_id': '5b708372925141405614d579',
#     'department': 'Crew',
#     'job': 'Transportation Captain'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1602870,
#     'known_for_department': 'Crew',
#     'name': 'Timothy E. Henley',
#     'original_name': 'Timothy E. Henley',
#     'popularity': 0.0368,
#     'profile_path': None,
#     'credit_id': '5b7083850e0a267ef4180e7c',
#     'department': 'Crew',
#     'job': 'Transportation Co-Captain'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1976175,
#     'known_for_department': 'Crew',
#     'name': 'John Placencia',
#     'original_name': 'John Placencia',
#     'popularity': 0.0143,
#     'profile_path': None,
#     'credit_id': '5b70839a0e0a267ef818817f',
#     'department': 'Crew',
#     'job': 'Video Assist Operator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1403423,
#     'known_for_department': 'Editing',
#     'name': 'Harry Muller',
#     'original_name': 'Harry Muller',
#     'popularity': 0.1248,
#     'profile_path': None,
#     'credit_id': '5b7083bfc3a3681899161ea9',
#     'department': 'Editing',
#     'job': 'Color Timer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1951591,
#     'known_for_department': 'Editing',
#     'name': 'Tristan M. Brighty',
#     'original_name': 'Tristan M. Brighty',
#     'popularity': 0.0953,
#     'profile_path': None,
#     'credit_id': '5b708402925141406817b1e0',
#     'department': 'Editing',
#     'job': 'First Assistant Editor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1578185,
#     'known_for_department': 'Lighting',
#     'name': 'Corwin A. Bibb',
#     'original_name': 'Corwin A. Bibb',
#     'popularity': 0.1236,
#     'profile_path': None,
#     'credit_id': '5b70842392514140541643fd',
#     'department': 'Lighting',
#     'job': 'Best Boy Electric'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2000147,
#     'known_for_department': 'Lighting',
#     'name': 'Christopher Franey',
#     'original_name': 'Christopher Franey',
#     'popularity': 0.0951,
#     'profile_path': None,
#     'credit_id': '5b7084340e0a267ee5171e80',
#     'department': 'Lighting',
#     'job': 'Best Boy Electrician'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2089465,
#     'known_for_department': 'Lighting',
#     'name': 'R. Michael Yope',
#     'original_name': 'R. Michael Yope',
#     'popularity': 0.0398,
#     'profile_path': None,
#     'credit_id': '5b7084490e0a267eeb192c86',
#     'department': 'Lighting',
#     'job': 'Electrician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1533787,
#     'known_for_department': 'Lighting',
#     'name': 'Louis DiCesare',
#     'original_name': 'Louis DiCesare',
#     'popularity': 0.1525,
#     'profile_path': None,
#     'credit_id': '5b708457925141405614d730',
#     'department': 'Lighting',
#     'job': 'Gaffer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1535308,
#     'known_for_department': 'Lighting',
#     'name': 'Mike Amorelli',
#     'original_name': 'Mike Amorelli',
#     'popularity': 0.0952,
#     'profile_path': None,
#     'credit_id': '5b7084690e0a267eeb192cc8',
#     'department': 'Lighting',
#     'job': 'Rigging Gaffer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1717528,
#     'known_for_department': 'Lighting',
#     'name': 'William Ambrose',
#     'original_name': 'William Ambrose',
#     'popularity': 0.0707,
#     'profile_path': None,
#     'credit_id': '5b70847cc3a36818861c670e',
#     'department': 'Lighting',
#     'job': 'Rigging Grip'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2042610,
#     'known_for_department': 'Production',
#     'name': 'Tim Hillman',
#     'original_name': 'Tim Hillman',
#     'popularity': 0.1387,
#     'profile_path': None,
#     'credit_id': '5b70849a0e0a267eeb192d31',
#     'department': 'Production',
#     'job': 'Location Manager'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105687,
#     'known_for_department': 'Production',
#     'name': 'Ron Segro',
#     'original_name': 'Ron Segro',
#     'popularity': 0.0891,
#     'profile_path': None,
#     'credit_id': '5b7084acc3a36818941c2218',
#     'department': 'Production',
#     'job': 'Post Production Accountant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105689,
#     'known_for_department': 'Production',
#     'name': 'Jackie Szymanski',
#     'original_name': 'Jackie Szymanski',
#     'popularity': 0.0143,
#     'profile_path': None,
#     'credit_id': '5b7084bc0e0a267ee718c720',
#     'department': 'Production',
#     'job': 'Production Accountant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1688607,
#     'known_for_department': 'Production',
#     'name': 'Shannon Hamed',
#     'original_name': 'Shannon Hamed',
#     'popularity': 0.0261,
#     'profile_path': None,
#     'credit_id': '5b7084c9c3a368189d16c8ba',
#     'department': 'Production',
#     'job': 'Production Coordinator'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1465491,
#     'known_for_department': 'Production',
#     'name': 'Robin Mulcahy Fisichella',
#     'original_name': 'Robin Mulcahy Fisichella',
#     'popularity': 0.2478,
#     'profile_path': None,
#     'credit_id': '5b7084eb0e0a267ef8188428',
#     'department': 'Production',
#     'job': 'Production Supervisor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1408849,
#     'known_for_department': 'Production',
#     'name': 'Flax Glor',
#     'original_name': 'Flax Glor',
#     'popularity': 0.1266,
#     'profile_path': None,
#     'credit_id': '5b7084fa0e0a267eed18bff7',
#     'department': 'Production',
#     'job': 'Publicist'},
#    {'adult': False,
#     'gender': 2,
#     'id': 57027,
#     'known_for_department': 'Production',
#     'name': "Louis D'Esposito",
#     'original_name': "Louis D'Esposito",
#     'popularity': 1.225,
#     'profile_path': '/mPy6hxHrHoEOWdljLyZM6DNBSPn.jpg',
#     'credit_id': '5b70850a925141404f14e087',
#     'department': 'Production',
#     'job': 'Unit Production Manager'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1408316,
#     'known_for_department': 'Sound',
#     'name': 'Lisa J. Levine',
#     'original_name': 'Lisa J. Levine',
#     'popularity': 0.7654,
#     'profile_path': None,
#     'credit_id': '5b70851ec3a36818861c689d',
#     'department': 'Sound',
#     'job': 'ADR Supervisor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2039720,
#     'known_for_department': 'Sound',
#     'name': 'Todd Harris',
#     'original_name': 'Todd Harris',
#     'popularity': 0.0645,
#     'profile_path': None,
#     'credit_id': '5b708537c3a36853750e6c25',
#     'department': 'Sound',
#     'job': 'Assistant Sound Editor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1335122,
#     'known_for_department': 'Sound',
#     'name': 'Donald Flick',
#     'original_name': 'Donald Flick',
#     'popularity': 0.2339,
#     'profile_path': None,
#     'credit_id': '5b70855592514140641761a9',
#     'department': 'Sound',
#     'job': 'Foley Editor'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1339459,
#     'known_for_department': 'Sound',
#     'name': 'Tanya Noel Hill',
#     'original_name': 'Tanya Noel Hill',
#     'popularity': 0.1122,
#     'profile_path': None,
#     'credit_id': '5b7085a80e0a267ef118220f',
#     'department': 'Sound',
#     'job': 'Music Editor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1738137,
#     'known_for_department': 'Sound',
#     'name': 'Tom Boyd',
#     'original_name': 'Tom Boyd',
#     'popularity': 0.2994,
#     'profile_path': '/7zQaVMgm0scxLlLEakPjAVqBTGj.jpg',
#     'credit_id': '5b7085bd0e0a267ef418129e',
#     'department': 'Sound',
#     'job': 'Musician'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1550566,
#     'known_for_department': 'Sound',
#     'name': 'Frank Bennett',
#     'original_name': 'Frank Bennett',
#     'popularity': 0.0884,
#     'profile_path': None,
#     'credit_id': '5b7085d20e0a267eed18c1d1',
#     'department': 'Sound',
#     'job': 'Orchestrator'},
#    {'adult': False,
#     'gender': 2,
#     'id': 554887,
#     'known_for_department': 'Sound',
#     'name': 'Stephen Hunter Flick',
#     'original_name': 'Stephen Hunter Flick',
#     'popularity': 0.2938,
#     'profile_path': '/s2Rxsbj39yrjrW0bZc90xCkNqJw.jpg',
#     'credit_id': '5b7085fb0e0a267ee718c98d',
#     'department': 'Sound',
#     'job': 'Sound Designer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1406242,
#     'known_for_department': 'Sound',
#     'name': 'Richard Burton',
#     'original_name': 'Richard Burton',
#     'popularity': 1.3572,
#     'profile_path': None,
#     'credit_id': '5b708611c3a36818861c6af6',
#     'department': 'Sound',
#     'job': 'Sound Effects Editor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1802558,
#     'known_for_department': 'Sound',
#     'name': 'Adam Blantz',
#     'original_name': 'Adam Blantz',
#     'popularity': 0.1181,
#     'profile_path': None,
#     'credit_id': '5b708627925141406a17b5c6',
#     'department': 'Sound',
#     'job': 'Sound Mixer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105693,
#     'known_for_department': 'Visual Effects',
#     'name': 'Mitch Gates',
#     'original_name': 'Mitch Gates',
#     'popularity': 0.0336,
#     'profile_path': None,
#     'credit_id': '5b70863ec3a368188817863a',
#     'department': 'Visual Effects',
#     'job': '3D Artist'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1934878,
#     'known_for_department': 'Visual Effects',
#     'name': 'Keith W. Smith',
#     'original_name': 'Keith W. Smith',
#     'popularity': 0.14,
#     'profile_path': None,
#     'credit_id': '5b70864ac3a3681888178659',
#     'department': 'Visual Effects',
#     'job': 'Animation Supervisor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1425486,
#     'known_for_department': 'Visual Effects',
#     'name': 'Enrique Bilsland',
#     'original_name': 'Enrique Bilsland',
#     'popularity': 0.0689,
#     'profile_path': None,
#     'credit_id': '5b70865b9251410341083306',
#     'department': 'Visual Effects',
#     'job': 'Mechanical Designer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1801523,
#     'known_for_department': 'Crew',
#     'name': 'Jon G. Belyeu',
#     'original_name': 'Jon G. Belyeu',
#     'popularity': 0.1409,
#     'profile_path': None,
#     'credit_id': '5b7086710e0a267ef11823d5',
#     'department': 'Visual Effects',
#     'job': 'Special Effects Supervisor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2105694,
#     'known_for_department': 'Visual Effects',
#     'name': 'Cris Borgnine',
#     'original_name': 'Cris Borgnine',
#     'popularity': 0.0404,
#     'profile_path': None,
#     'credit_id': '5b7086850e0a267eed18c34f',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1399633,
#     'known_for_department': 'Visual Effects',
#     'name': 'Greg Baxter',
#     'original_name': 'Greg Baxter',
#     'popularity': 0.1594,
#     'profile_path': None,
#     'credit_id': '5b7086950e0a267ef1182415',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Coordinator'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1442512,
#     'known_for_department': 'Visual Effects',
#     'name': 'Timothy Eaton',
#     'original_name': 'Timothy Eaton',
#     'popularity': 0.0829,
#     'profile_path': None,
#     'credit_id': '5b7086ae0e0a267ef818882e',
#     'department': 'Crew',
#     'job': 'Visual Effects Editor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1404722,
#     'known_for_department': 'Visual Effects',
#     'name': 'Joseph B. Conmy IV',
#     'original_name': 'Joseph B. Conmy IV',
#     'popularity': 0.9207,
#     'profile_path': None,
#     'credit_id': '5b7086c7c3a368188817877f',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Producer'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1404731,
#     'known_for_department': 'Visual Effects',
#     'name': 'Joe Bauer',
#     'original_name': 'Joe Bauer',
#     'popularity': 0.2063,
#     'profile_path': None,
#     'credit_id': '5b7086dd925141404f14e3ca',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Supervisor'},
#    {'adult': False,
#     'gender': 1,
# ...
#     'credit_id': '5d06b86bc3a368489e267376',
#     'department': 'Art',
#     'job': 'Assistant Property Master'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2219998,
#     'known_for_department': 'Art',
#     'name': 'Chris John Jones',
#     'original_name': 'Chris John Jones',
#     'popularity': 0.1018,
#     'profile_path': None,
#     'credit_id': '5d06b88492514104c4bc3374',
#     'department': 'Art',
#     'job': 'Creative Director'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1652450,
#     'known_for_department': 'Art',
#     'name': 'Joey Genitempo',
#     'original_name': 'Joey Genitempo',
#     'popularity': 0.0643,
#     'profile_path': None,
#     'credit_id': '5d06b8a60e0a260b0ad1d3c5',
#     'department': 'Art',
#     'job': 'Set Painter'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1957619,
#     'known_for_department': 'Art',
#     'name': 'Eric Ramsey',
#     'original_name': 'Eric Ramsey',
#     'popularity': 0.1714,
#     'profile_path': None,
#     'credit_id': '5d06b8b79251413f2dbe4b5d',
#     'department': 'Art',
#     'job': 'Storyboard Artist'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2116310,
#     'known_for_department': 'Art',
#     'name': 'Randy Severino',
#     'original_name': 'Randy Severino',
#     'popularity': 0.0812,
#     'profile_path': None,
#     'credit_id': '5d06b8c2c3a3684adb2c13ea',
#     'department': 'Art',
#     'job': 'Swing'},
#    {'adult': False,
#     'gender': 2,
#     'id': 994550,
#     'known_for_department': 'Art',
#     'name': 'Kyle Cooper',
#     'original_name': 'Kyle Cooper',
#     'popularity': 0.2441,
#     'profile_path': '/9T9nRzgkaesN6q1Wsp4O6kkTQtB.jpg',
#     'credit_id': '5d06b92792514163d1c04522',
#     'department': 'Art',
#     'job': 'Title Designer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2339741,
#     'known_for_department': 'Sound',
#     'name': 'Michael London',
#     'original_name': 'Michael London',
#     'popularity': 0.0214,
#     'profile_path': None,
#     'credit_id': '5d06b9449251411a82ccb3c2',
#     'department': 'Sound',
#     'job': 'ADR Recordist'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1374169,
#     'known_for_department': 'Sound',
#     'name': 'Michael J. Broomberg',
#     'original_name': 'Michael J. Broomberg',
#     'popularity': 0.1547,
#     'profile_path': None,
#     'credit_id': '5d06b94f9251413f2dbe4c1a',
#     'department': 'Sound',
#     'job': 'Foley Artist'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1435190,
#     'known_for_department': 'Sound',
#     'name': 'Kyle Rochlin',
#     'original_name': 'Kyle Rochlin',
#     'popularity': 0.171,
#     'profile_path': None,
#     'credit_id': '5d06b9639251413f2dbe4c2e',
#     'department': 'Sound',
#     'job': 'Foley Mixer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1791928,
#     'known_for_department': 'Sound',
#     'name': 'Philip A. Schwartz',
#     'original_name': 'Philip A. Schwartz',
#     'popularity': 0.0522,
#     'profile_path': None,
#     'credit_id': '5d06b9759251413f2dbe4c5e',
#     'department': 'Sound',
#     'job': 'Utility Sound'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1412199,
#     'known_for_department': 'Crew',
#     'name': 'John J. Downey',
#     'original_name': 'John J. Downey',
#     'popularity': 0.1285,
#     'profile_path': None,
#     'credit_id': '5d06b9849251410c6aba4981',
#     'department': 'Crew',
#     'job': 'Special Effects Technician'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2305836,
#     'known_for_department': 'Visual Effects',
#     'name': 'Bob Lloyd',
#     'original_name': 'Bob Lloyd',
#     'popularity': 0.0665,
#     'profile_path': None,
#     'credit_id': '5d06b993925141488aba5d63',
#     'department': 'Visual Effects',
#     'job': 'VFX Artist'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1399299,
#     'known_for_department': 'Crew',
#     'name': 'Patrick Ballin',
#     'original_name': 'Patrick Ballin',
#     'popularity': 0.0966,
#     'profile_path': None,
#     'credit_id': '5d06b9a5c3a3684adb2c15da',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Assistant Editor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1573468,
#     'known_for_department': 'Visual Effects',
#     'name': 'Ken Dackermann',
#     'original_name': 'Ken Dackermann',
#     'popularity': 0.0824,
#     'profile_path': None,
#     'credit_id': '5d06b9b8c3a36877db221b23',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Compositor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2098314,
#     'known_for_department': 'Visual Effects',
#     'name': 'Anthony Kramer',
#     'original_name': 'Anthony Kramer',
#     'popularity': 0.0914,
#     'profile_path': None,
#     'credit_id': '5d06b9cf925141488aba5dab',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Production Assistant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1637392,
#     'known_for_department': 'Visual Effects',
#     'name': 'Marion Spates',
#     'original_name': 'Marion Spates',
#     'popularity': 0.1674,
#     'profile_path': None,
#     'credit_id': '5d06b9eec3a368753f2048c6',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Production Manager'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2339744,
#     'known_for_department': 'Visual Effects',
#     'name': 'Brian Adams',
#     'original_name': 'Brian Adams',
#     'popularity': 0.0698,
#     'profile_path': None,
#     'credit_id': '5d06ba220e0a260b0ad1d629',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Technical Director'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1553252,
#     'known_for_department': 'Camera',
#     'name': 'Will Dearborn',
#     'original_name': 'Will Dearborn',
#     'popularity': 0.1696,
#     'profile_path': None,
#     'credit_id': '5d06ba320e0a260b0ad1d62f',
#     'department': 'Camera',
#     'job': 'Additional Second Assistant Camera'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1913993,
#     'known_for_department': 'Camera',
#     'name': 'Matthew A. Del Ruth',
#     'original_name': 'Matthew A. Del Ruth',
#     'popularity': 0.0675,
#     'profile_path': None,
#     'credit_id': '5d06ba440e0a267080cc0e14',
#     'department': 'Camera',
#     'job': 'Assistant Camera'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1549439,
#     'known_for_department': 'Camera',
#     'name': 'Markus Mentzer',
#     'original_name': 'Markus Mentzer',
#     'popularity': 0.2346,
#     'profile_path': '/wNlX24rSyLVPHG8Gf93Kzvz7x6M.jpg',
#     'credit_id': '5d06c403c3a36808702262a3',
#     'department': 'Camera',
#     'job': 'Camera Loader'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1930935,
#     'known_for_department': 'Camera',
#     'name': 'Arthur Blum',
#     'original_name': 'Arthur Blum',
#     'popularity': 0.1505,
#     'profile_path': None,
#     'credit_id': '5d06c412c3a3680a5722853f',
#     'department': 'Camera',
#     'job': 'Dolly Grip'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1641321,
#     'known_for_department': 'Production',
#     'name': 'Jessica Daniels',
#     'original_name': 'Jessica Daniels',
#     'popularity': 0.1459,
#     'profile_path': '/OCFMp6OLapCV1uOUxQ8vJgajjw.jpg',
#     'credit_id': '5d06c44dc3a3684adb2c3036',
#     'department': 'Production',
#     'job': 'Casting Assistant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2339771,
#     'known_for_department': 'Editing',
#     'name': 'Stacey Frederick',
#     'original_name': 'Stacey Frederick',
#     'popularity': 0.0281,
#     'profile_path': None,
#     'credit_id': '5d06c46392514110b7ba34a2',
#     'department': 'Editing',
#     'job': 'Assistant Editor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1838780,
#     'known_for_department': 'Editing',
#     'name': 'Paul McGhee',
#     'original_name': 'Paul McGhee',
#     'popularity': 0.1617,
#     'profile_path': None,
#     'credit_id': '5d06c470c3a368445b2e0188',
#     'department': 'Editing',
#     'job': 'Digital Color Timer'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1634460,
#     'known_for_department': 'Editing',
#     'name': 'Natasha Leonnet',
#     'original_name': 'Natasha Leonnet',
#     'popularity': 0.6679,
#     'profile_path': None,
#     'credit_id': '5d06c4820e0a260eddce2ada',
#     'department': 'Editing',
#     'job': 'Digital Colorist'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1405242,
#     'known_for_department': 'Editing',
#     'name': 'Donnie Creighton',
#     'original_name': 'Donnie Creighton',
#     'popularity': 0.132,
#     'profile_path': None,
#     'credit_id': '5d06c4970e0a26511fcbd635',
#     'department': 'Editing',
#     'job': 'Digital Intermediate Assistant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1748028,
#     'known_for_department': 'Editing',
#     'name': 'Boyd Steer',
#     'original_name': 'Boyd Steer',
#     'popularity': 0.1059,
#     'profile_path': None,
#     'credit_id': '5d06c4a10e0a266424cc1dbb',
#     'department': 'Editing',
#     'job': 'Negative Cutter'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1855157,
#     'known_for_department': 'Production',
#     'name': 'Darrin Lipscomb',
#     'original_name': 'Darrin Lipscomb',
#     'popularity': 0.0741,
#     'profile_path': None,
#     'credit_id': '5d06c4b40e0a267080cc2605',
#     'department': 'Production',
#     'job': 'Assistant Location Manager'},
#    {'adult': False,
#     'gender': 2,
#     'id': 4500,
#     'known_for_department': 'Sound',
#     'name': 'John Debney',
#     'original_name': 'John Debney',
#     'popularity': 0.6472,
#     'profile_path': '/iUwBpunUEdknzkRpgAyodwIEh4n.jpg',
#     'credit_id': '5d06c4c992514104c4bc4d7c',
#     'department': 'Sound',
#     'job': 'Conductor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2217701,
#     'known_for_department': 'Production',
#     'name': 'Kevin Roy',
#     'original_name': 'Kevin Roy',
#     'popularity': 0.074,
#     'profile_path': None,
#     'credit_id': '5d06c4dc9251413f2dbe6228',
#     'department': 'Production',
#     'job': 'Additional Production Assistant'},
#    {'adult': False,
#     'gender': 2,
#     'id': 2339774,
#     'known_for_department': 'Art',
#     'name': 'Zack Heath',
#     'original_name': 'Zack Heath',
#     'popularity': 0.0943,
#     'profile_path': None,
#     'credit_id': '5d06c4fdc3a368445b2e05e7',
#     'department': 'Production',
#     'job': 'Art Department Production Assistant'},
#    {'adult': False,
#     'gender': 1,
#     'id': 2339775,
#     'known_for_department': 'Production',
#     'name': 'Michelle A. De Mayo',
#     'original_name': 'Michelle A. De Mayo',
#     'popularity': 0.0453,
#     'profile_path': None,
#     'credit_id': '5d06c508c3a368087022656a',
#     'department': 'Production',
#     'job': 'Assistant Accountant'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1914010,
#     'known_for_department': 'Lighting',
#     'name': 'Harold Groshon',
#     'original_name': 'Harold Groshon',
#     'popularity': 0.0877,
#     'profile_path': None,
#     'credit_id': '5d06c516c3a36832f222754c',
#     'department': 'Lighting',
#     'job': 'Assistant Chief Lighting Technician'},
#    {'adult': False,
#     'gender': 1,
#     'id': 2233154,
#     'known_for_department': 'Production',
#     'name': 'Lisa Joelle Curtis',
#     'original_name': 'Lisa Joelle Curtis',
#     'popularity': 0.4909,
#     'profile_path': None,
#     'credit_id': '5d06c5239251413f2dbe6282',
#     'department': 'Production',
#     'job': 'Assistant Production Coordinator'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1170987,
#     'known_for_department': 'Lighting',
#     'name': 'Alex Skvorzov',
#     'original_name': 'Alex Skvorzov',
#     'popularity': 0.0389,
#     'profile_path': None,
#     'credit_id': '5d06c53392514163d1c05fd8',
#     'department': 'Lighting',
#     'job': 'Chief Lighting Technician'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2313699,
#     'known_for_department': 'Visual Effects',
#     'name': 'Erik Bruhwiler',
#     'original_name': 'Erik Bruhwiler',
#     'popularity': 0.1001,
#     'profile_path': None,
#     'credit_id': '5d06c551c3a3684adb2c34c0',
#     'department': 'Visual Effects',
#     'job': 'Digital Compositor'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2218519,
#     'known_for_department': 'Production',
#     'name': 'Jennifer Bender',
#     'original_name': 'Jennifer Bender',
#     'popularity': 0.0781,
#     'profile_path': None,
#     'credit_id': '5d06c5639251413f2dbe62d1',
#     'department': 'Production',
#     'job': 'Extras Casting'},
#    {'adult': False,
#     'gender': 0,
#     'id': 6063,
#     'known_for_department': 'Visual Effects',
#     'name': 'Kristen Branan',
#     'original_name': 'Kristen Branan',
#     'popularity': 0.1639,
#     'profile_path': None,
#     'credit_id': '5d06c58cc3a3684adb2c34f2',
#     'department': 'Production',
#     'job': 'Head of Production'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2320826,
#     'known_for_department': 'Crew',
#     'name': 'Emily Mann',
#     'original_name': 'Emily Mann',
#     'popularity': 0.082,
#     'profile_path': None,
#     'credit_id': '5d06c59f0e0a267080cc27d9',
#     'department': 'Crew',
#     'job': 'Intern'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1648088,
#     'known_for_department': 'Lighting',
#     'name': 'Scott Barnes',
#     'original_name': 'Scott Barnes',
#     'popularity': 0.809,
#     'profile_path': None,
#     'credit_id': '5d06c5bcc3a3680a57228750',
#     'department': 'Lighting',
#     'job': 'Lighting Programmer'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2313707,
#     'known_for_department': 'Production',
#     'name': 'Wes Denton',
#     'original_name': 'Wes Denton',
#     'popularity': 0.0577,
#     'profile_path': None,
#     'credit_id': '5d06c5cd0e0a267fa9ce0909',
#     'department': 'Production',
#     'job': 'Production Assistant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2250609,
#     'known_for_department': 'Production',
#     'name': 'Jeff Barnes',
#     'original_name': 'Jeff Barnes',
#     'popularity': 0.1627,
#     'profile_path': None,
#     'credit_id': '5d06c5dd0e0a261357d1ae59',
#     'department': 'Production',
#     'job': 'Production Executive'},
#    {'adult': False,
#     'gender': 1,
#     'id': 1064447,
#     'known_for_department': 'Production',
#     'name': 'Sandra J. Smith',
#     'original_name': 'Sandra J. Smith',
#     'popularity': 0.0414,
#     'profile_path': None,
#     'credit_id': '5d06c5ee925141131bbc75de',
#     'department': 'Production',
#     'job': 'Production Secretary'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2339780,
#     'known_for_department': 'Visual Effects',
#     'name': 'Nina Harlan',
#     'original_name': 'Nina Harlan',
#     'popularity': 0.0591,
#     'profile_path': None,
#     'credit_id': '5d06c5fec3a3680870226675',
#     'department': 'Visual Effects',
#     'job': 'Rotoscoping Artist'},
#    {'adult': False,
#     'gender': 0,
#     'id': 2339781,
#     'known_for_department': 'Production',
#     'name': 'Tracy Browne',
#     'original_name': 'Tracy Browne',
#     'popularity': 0.0454,
#     'profile_path': None,
#     'credit_id': '5d06c60cc3a3684adb2c3562',
#     'department': 'Production',
#     'job': 'Second Assistant Accountant'},
#    {'adult': False,
#     'gender': 0,
#     'id': 1388876,
#     'known_for_department': 'Visual Effects',
#     'name': 'Peter G. Travers',
#     'original_name': 'Peter G. Travers',
#     'popularity': 0.103,
#     'profile_path': None,
#     'credit_id': '5d38e27ee54d5d16dfdab74b',
#     'department': 'Visual Effects',
#     'job': 'Visual Effects Supervisor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1181213,
#     'known_for_department': 'Visual Effects',
#     'name': 'Leandro Visconti',
#     'original_name': 'Leandro Visconti',
#     'popularity': 0.0818,
#     'profile_path': None,
#     'credit_id': '5d3b36e2b9a0bd0010a2c82c',
#     'department': 'Visual Effects',
#     'job': 'Compositing Supervisor'},
#    {'adult': False,
#     'gender': 2,
#     'id': 5112053,
#     'known_for_department': 'Crew',
#     'name': 'Patrick Jackson',
#     'original_name': 'Patrick Jackson',
#     'popularity': 0.0723,
#     'profile_path': None,
#     'credit_id': '6758ef70a6347ac4d38739b9',
#     'department': 'Crew',
#     'job': 'Studio Teacher'},
#    {'adult': False,
#     'gender': 2,
#     'id': 1641671,
#     'known_for_department': 'Camera',
#     'name': 'Andrew Shulkind',
#     'original_name': 'Andrew Shulkind',
#     'popularity': 0.1523,
#     'profile_path': '/p0bWYP2m2Rnoa0eV9aGccS4eSuK.jpg',
#     'credit_id': '68b7270839a2115ab81f31d0',
#     'department': 'Camera',
#     'job': 'Libra Head Technician'}]}}

# %% [markdown]
# # Scraping tmdb data:

# %%
needed = True
if (needed==True): 
    data = {
    "Book" : [],
    "author_book": [],
    "Film" : [],
    "date_film" : [],
    "runtime" : [],
    "original_language":[],
    "votes_film" : [],
    "overview_film" : [],
    "vote_count_film" : [],
    "popularity_film" : [],
    "budget_film" : [],
    "revenue_film" : [],
    "Genre" : [],
    "Director" : [],
    "Actor1" : [],
    "Actor2" : [],
    "Actor3" : []
}
    for i in tqdm(range(len(df))):
        n = df["Film"][i]
        y = df["Year_film"][i]
        k = tmdb_search_movie(n,year=y)
        if k is not None and "id" in list(k.keys()):
            k = tmdb_get_movie_details(k["id"])
        if k is not None:
            data["votes_film"].append(k["vote_average"])
            data["Film"].append(k["original_title"])
            data["date_film"].append(k["release_date"])
            data["overview_film"].append(k["overview"])        
            data["vote_count_film"].append(k["vote_count"])
            data["popularity_film"].append(k["popularity"])
            data["Genre"].append(k["genres"])
            data["original_language"].append(k["original_language"])
            data["runtime"].append(k["runtime"])
            direc = None
            if 'credits' in k and 'crew' in k['credits']:
                for person in k['credits']['crew']:
                    if person['job'] == 'Director':
                        data["Director"].append(person['name'])
                        direc = person['name']
                        break
            if direc is None:
                data['Director'].append(np.nan)
            if 'credits' in k and 'cast' in k['credits']:
                for i in range(min(3, len(k['credits']['cast']))):
                    data[f"Actor{i+1}"].append(k['credits']['cast'][i]['name'])
                if len(k['credits']['cast']) < 3:
                    for i in range(len(k['credits']['cast']), 3):
                        data[f"Actor{i+1}"].append(np.nan)
    
            if "budget" in list(k.keys()):
                data["budget_film"].append(k["budget"])
            else: 
                data["budget_film"].append(np.nan)
            if "revenue" in list(k.keys()): 
                data["revenue_film"].append(k["revenue"])
            else: 
                data["revenue_film"].append(np.nan)
        else: 
            data["votes_film"].append(np.nan)
            data["Film"].append(n)
            data["date_film"].append(str(y))
            data["overview_film"].append(np.nan)
            data["vote_count_film"].append(np.nan)
            data["popularity_film"].append(np.nan)
            data["budget_film"].append(np.nan)
            data["revenue_film"].append(np.nan)
            data["Genre"].append(np.nan)
            data["Director"].append(np.nan)
            data["Actor1"].append(np.nan)
            data["Actor2"].append(np.nan)
            data["Actor3"].append(np.nan)
            data["original_language"].append(np.nan)
            data["runtime"].append(np.nan)
        data["Book"].append(df["Book"][i])
        data["author_book"].append(df["author_book"][i])
    df = pd.DataFrame(data)
    df.to_csv("data/raw/movie_adaptation_list.csv")
    display(df)
else:
    for i in data.keys():
        print(len(data[i]),i)
# Out:
# 100%|███████████████████████████████████████████| 5810/5810 [18:35<00:00,  5.21it/s]
#                                  Book      author_book  \
# 0                4.50 from Paddington  Agatha Christie
# 1                4.50 from Paddington  Agatha Christie
# 2                4.50 from Paddington  Agatha Christie
# 3                4.50 from Paddington  Agatha Christie
# 4                4.50 from Paddington  Agatha Christie
# ...                               ...              ...
# 5805             4.50 from Paddington  Agatha Christie
# 5806             4.50 from Paddington  Agatha Christie
# 5807             4.50 from Paddington  Agatha Christie
# 5808             4.50 from Paddington  Agatha Christie
# 5809  Zenon: Girl of the 21st Century   Marilyn Sadler
#
#                                  Film   date_film  runtime original_language  \
# 0                           25th Hour  2002-12-19    135.0                en
# 1                             グラスホッパー  2015-11-07    119.0                ja
# 2                     Murder She Said  1961-09-26     87.0                en
# 3          Le crime est notre affaire  2008-10-02    109.0                fr
# 4                          Die Hard 2  1990-07-03    124.0                en
# ...                               ...         ...      ...               ...
# 5805                  Z for Zachariah  2015-08-13     97.0                en
# 5806       Zathura: A Space Adventure  2005-11-06    101.0                en
# 5807  Zenon: Girl of the 21st Century  1999-01-23     97.0                en
# 5808                Zenon: The Zequel  2001-01-12     89.0                en
# 5809                        Zenon: Z3        2003      NaN               NaN
#
#       votes_film                                      overview_film  \
# 0          7.320  In New York City in the days following the eve...
# 1          5.800  Movie contains the stories of three people: Su...
# 2          7.316  Miss Marple believes she's seen a murder in a ...
# 3          5.883  Loosely based on "4.50 from Paddington" by Aga...
# 4          7.000  One year after his heroics in Los Angeles, Joh...
# ...          ...                                                ...
# 5805       5.687  In the wake of a nuclear war, a young woman su...
# 5806       6.430  After their father is called into work, two yo...
# 5807       6.000  Zenon Kar, a 13-year-old girl who lives on a s...
# 5808       5.600  Zenon Kar is 15 and lives on a space station w...
# 5809         NaN                                                NaN
#
#       vote_count_film  popularity_film  budget_film  revenue_film  \
# 0              2463.0           1.5834    5000000.0    23932055.0
# 1                13.0           3.7769          0.0           0.0
# 2               220.0           1.5202          0.0           0.0
# 3                94.0           1.5241   12000000.0           0.0
# 4              6138.0           8.8950   70000000.0   240031094.0
# ...               ...              ...          ...           ...
# 5805            966.0           3.3732          0.0      121461.0
# 5806           3442.0           4.5906   65000000.0    65079104.0
# 5807            183.0           1.1902          0.0           0.0
# 5808            108.0           1.5166          0.0           0.0
# 5809              NaN              NaN          NaN           NaN
#
#                                                   Genre           Director  \
# 0     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...          Spike Lee
# 1     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...  Tomoyuki Takimoto
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...     George Pollock
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      Pascal Thomas
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...       Renny Harlin
# ...                                                 ...                ...
# 5805  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...        Craig Zobel
# 5806  [{'id': 878, 'name': 'Science Fiction'}, {'id'...        Jon Favreau
# 5807  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...    Kenneth Johnson
# 5808  [{'id': 10751, 'name': 'Family'}, {'id': 10770...         Manny Coto
# 5809                                                NaN                NaN
#
#                    Actor1                  Actor2          Actor3
# 0           Edward Norton  Philip Seymour Hoffman    Barry Pepper
# 1          Tadanobu Asano              Toma Ikuta  Ryosuke Yamada
# 2     Margaret Rutherford          Arthur Kennedy   Muriel Pavlow
# 3          Catherine Frot        André Dussollier     Claude Rich
# 4            Bruce Willis          Bonnie Bedelia  William Sadler
# ...                   ...                     ...             ...
# 5805        Margot Robbie        Chiwetel Ejiofor      Chris Pine
# 5806      Josh Hutcherson              Jonah Bobo     Dax Shepard
# 5807       Kirsten Storms            Raven-Symoné   Stuart Pankin
# 5808       Kirsten Storms          Shadia Simmons   Lauren Maltby
# 5809                  NaN                     NaN             NaN
#
# [5810 rows x 17 columns]

# %%
import json
df = pd.read_csv("data/raw/movie_adaptation_list.csv")
df["Book"] = df["Book"].str.lower()
df2 = pd.read_csv("data/raw/booksummaries.csv",sep="\t")
df2.columns=["a1","a2","Book","Author","Year","Genre","Overview"]
df2 = df2.drop(columns=["a1","a2"])
df2["Book"] = df2["Book"].str.lower()
genres = []
for i in df2["Genre"]:
    if isinstance(i,str):
        genres.append(list(json.loads(i).values()))
    else:
        genres.append(np.nan)
df2["Genre"] = genres
overviews = []
genres = []
for i in df["Book"]:
    overview = np.nan
    genre = np.nan
    if (df2["Book"] == i).any():
        overview = df2.loc[df2["Book"] == i, "Overview"].iloc[0]
        genre = df2.loc[df2["Book"] == i, "Genre"].iloc[0]
    overviews.append(overview)
    genres.append(genre)
df["overview_book"] = overviews
df["Genre_book"] = genres
df
# Out:
#       Unnamed: 0                             Book      author_book  \
# 0              0             4.50 from paddington  Agatha Christie
# 1              1             4.50 from paddington  Agatha Christie
# 2              2             4.50 from paddington  Agatha Christie
# 3              3             4.50 from paddington  Agatha Christie
# 4              4             4.50 from paddington  Agatha Christie
# ...          ...                              ...              ...
# 5805        5805             4.50 from paddington  Agatha Christie
# 5806        5806             4.50 from paddington  Agatha Christie
# 5807        5807             4.50 from paddington  Agatha Christie
# 5808        5808             4.50 from paddington  Agatha Christie
# 5809        5809  zenon: girl of the 21st century   Marilyn Sadler
#
#                                  Film   date_film  runtime original_language  \
# 0                           25th Hour  2002-12-19    135.0                en
# 1                             グラスホッパー  2015-11-07    119.0                ja
# 2                     Murder She Said  1961-09-26     87.0                en
# 3          Le crime est notre affaire  2008-10-02    109.0                fr
# 4                          Die Hard 2  1990-07-03    124.0                en
# ...                               ...         ...      ...               ...
# 5805                  Z for Zachariah  2015-08-13     97.0                en
# 5806       Zathura: A Space Adventure  2005-11-06    101.0                en
# 5807  Zenon: Girl of the 21st Century  1999-01-23     97.0                en
# 5808                Zenon: The Zequel  2001-01-12     89.0                en
# 5809                        Zenon: Z3        2003      NaN               NaN
#
#       votes_film                                      overview_film  \
# 0          7.320  In New York City in the days following the eve...
# 1          5.800  Movie contains the stories of three people: Su...
# 2          7.316  Miss Marple believes she's seen a murder in a ...
# 3          5.883  Loosely based on "4.50 from Paddington" by Aga...
# 4          7.000  One year after his heroics in Los Angeles, Joh...
# ...          ...                                                ...
# 5805       5.687  In the wake of a nuclear war, a young woman su...
# 5806       6.430  After their father is called into work, two yo...
# 5807       6.000  Zenon Kar, a 13-year-old girl who lives on a s...
# 5808       5.600  Zenon Kar is 15 and lives on a space station w...
# 5809         NaN                                                NaN
#
#       vote_count_film  popularity_film  budget_film  revenue_film  \
# 0              2463.0           1.5834    5000000.0    23932055.0
# 1                13.0           3.7769          0.0           0.0
# 2               220.0           1.5202          0.0           0.0
# 3                94.0           1.5241   12000000.0           0.0
# 4              6138.0           8.8950   70000000.0   240031094.0
# ...               ...              ...          ...           ...
# 5805            966.0           3.3732          0.0      121461.0
# 5806           3442.0           4.5906   65000000.0    65079104.0
# 5807            183.0           1.1902          0.0           0.0
# 5808            108.0           1.5166          0.0           0.0
# 5809              NaN              NaN          NaN           NaN
#
#                                                   Genre           Director  \
# 0     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...          Spike Lee
# 1     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...  Tomoyuki Takimoto
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...     George Pollock
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...      Pascal Thomas
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...       Renny Harlin
# ...                                                 ...                ...
# 5805  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...        Craig Zobel
# 5806  [{'id': 878, 'name': 'Science Fiction'}, {'id'...        Jon Favreau
# 5807  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...    Kenneth Johnson
# 5808  [{'id': 10751, 'name': 'Family'}, {'id': 10770...         Manny Coto
# 5809                                                NaN                NaN
#
#                    Actor1                  Actor2          Actor3  \
# 0           Edward Norton  Philip Seymour Hoffman    Barry Pepper
# 1          Tadanobu Asano              Toma Ikuta  Ryosuke Yamada
# 2     Margaret Rutherford          Arthur Kennedy   Muriel Pavlow
# 3          Catherine Frot        André Dussollier     Claude Rich
# 4            Bruce Willis          Bonnie Bedelia  William Sadler
# ...                   ...                     ...             ...
# 5805        Margot Robbie        Chiwetel Ejiofor      Chris Pine
# 5806      Josh Hutcherson              Jonah Bobo     Dax Shepard
# 5807       Kirsten Storms            Raven-Symoné   Stuart Pankin
# 5808       Kirsten Storms          Shadia Simmons   Lauren Maltby
# 5809                  NaN                     NaN             NaN
#
#                                           overview_book  \
# 0      Elspeth McGillicuddy has come from Scotland t...
# 1      Elspeth McGillicuddy has come from Scotland t...
# 2      Elspeth McGillicuddy has come from Scotland t...
# 3      Elspeth McGillicuddy has come from Scotland t...
# 4      Elspeth McGillicuddy has come from Scotland t...
# ...                                                 ...
# 5805   Elspeth McGillicuddy has come from Scotland t...
# 5806   Elspeth McGillicuddy has come from Scotland t...
# 5807   Elspeth McGillicuddy has come from Scotland t...
# 5808   Elspeth McGillicuddy has come from Scotland t...
# 5809                                                NaN
#
#                                              Genre_book
# 0     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 1     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 2     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 3     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 4     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# ...                                                 ...
# 5805  [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 5806  [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 5807  [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 5808  [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 5809                                                NaN
#
# [5810 rows x 20 columns]

# %%
import numpy as np
count_nan_year = (df["date_film"].isnull()).sum().sum()
count_nan_genre = (df["Genre"].isnull()).sum().sum()
count_nan_overview_film = (df["overview_film"].isnull()).sum().sum()
count_nan_overview_book = (df["overview_book"].isnull()).sum().sum()
count_nan_overview_filmandbook = (df["overview_book"].isnull() | df["overview_film"].isnull()).sum().sum()
print(f'{count_nan_year =}')
print(f'{count_nan_genre =}')
print(f'{count_nan_overview_film =}')
print(f'{count_nan_overview_book =}')
print(f'{count_nan_overview_filmandbook =}')
# Out:
# count_nan_year =np.int64(11)
# count_nan_genre =np.int64(523)
# count_nan_overview_film =np.int64(559)
# count_nan_overview_book =np.int64(318)
# count_nan_overview_filmandbook =np.int64(559)

# %%
plt.hist(df["vote_count_film"])
plt.show()
# Out:
# (array([4.842e+03, 2.310e+02, 9.700e+01, 3.900e+01, 2.900e+01, 1.900e+01,
#         1.400e+01, 8.000e+00, 3.000e+00, 5.000e+00]),
#  array([    0. ,  3095.2,  6190.4,  9285.6, 12380.8, 15476. , 18571.2,
#         21666.4, 24761.6, 27856.8, 30952. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["vote_count_film"])
plt.show()<
