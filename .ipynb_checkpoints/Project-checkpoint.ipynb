# %%
# %load_ext autoreload
# %autoreload 2
from src.data_collection import *

# %%
import os
os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/clean", exist_ok=True)
os.makedirs("data/compressed", exist_ok=True)
# Out:
# ['(2005)']

# %% [markdown]
# # Data scraping from wikipedia lists

# %%
urls = [
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(0-9,_A-C)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(D-J)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(K-R)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(S-Z)",
"http://en.wikipedia.org/wiki/List_of_short_fiction_made_into_feature_films",
"https://en.wikipedia.org/wiki/List_of_children%27s_books_made_into_feature_films",
#"https://en.wikipedia.org/wiki/List_of_films_based_on_comics"
]
df = scrape_wikipedia_list(urls)
df.to_csv("data/movie_adaptation_list.csv")
df.columns=['Book', 'Film',"Year"]

df # fix later
# Out:
#                                                    Book  \
# 0                     The 25th Hour(2001),David Benioff
# 1     3 Assassins(グラスホッパー,Gurasuhoppā)(2004),Kōtarō ...
# 2            4.50 from Paddington(1957),Agatha Christie
# 3            4.50 from Paddington(1957),Agatha Christie
# 4                         58 Minutes(1987),Walter Wager
# ...                                                 ...
# 5805            Z for Zachariah(1974),Robert C. O'Brien
# 5806                   Zathura(2002),Chris Van Allsburg
# 5807  Zenon: Girl of the 21st Century(1997),Marilyn ...
# 5808  Zenon: Girl of the 21st Century(1997),Marilyn ...
# 5809  Zenon: Girl of the 21st Century(1997),Marilyn ...
#
#                                  Film  Year
# 0                           25th Hour  2002
# 1                         Grasshopper  2015
# 2                    Murder, She Said  1961
# 3               Crime Is Our Business  2008
# 4                          Die Hard 2  1990
# ...

# %%
print(r)
# Out:
# {'adult': False, 'backdrop_path': '/mpfRchw4jh2cEBajB9EJltTnDH2.jpg', 'genre_ids': [80, 18], 'id': 1429, 'original_language': 'en', 'original_title': '25th Hour', 'overview': 'In New York City in the days following the events of 9/11, Monty Brogan is a convicted drug dealer about to start a seven-year prison sentence, and his final hours of freedom are devoted to hanging out with his closest buddies and trying to prepare his girlfriend for his extended absence.', 'popularity': 3.4212, 'poster_path': '/uW7tTRElr2tRhmAVESzvHy4ByXg.jpg', 'release_date': '2002-12-19', 'title': '25th Hour', 'video': False, 'vote_average': 7.322, 'vote_count': 2462}

# %%
tmdb_votes = []
data = {
    "Book" : [],
    "Film" : [],
    "votes" : [],
    "overview" : []
}
for i in range(len(df)):
    n = df["Film"][i]
    y = df["Year"][i]
    k = tmdb_search_movie(n,year=y)
    if k is not None: 
        data["votes"].append(k["vote_average"])
        film.append(k["original_title"])
        date.append(k["release_date"])
        overview.append(k["overview"])
    else: 
        tmdb_votes.append(-1)
        film.append(n)
        date.append(str(y))
        overview.append(-1)
    book.append(df["Book"][i])
df = DataFrame(column=["Book", "Film", "Date", "Overview"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 9
#       7 n = df["Film"][i]
#       8 y = df["Year"][i]
# ----> 9 k = tmdb_search_movie(n,year=y)
#      10 if k is not None:
#      11     tmdb_votes.append(k["vote_average"])
#
# File ~/GitProjs/DALAS-project/src/data_collection.py:61, in tmdb_search_movie(title, year, api_key, strict)
#      59 if year:
#      60     params["year"] = year
# ---> 61 r = requests.get("https://api.themoviedb.org/3/search/movie", params=params)
#      62 r.raise_for_status()
#      63 data = r.json()
#
# File ~/GitProjs/DALAS-project/dalas_env/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
# ...

# %%
df
