# %%
# %load_ext autoreload
# %autoreload 2
from src.data_collection import *
from src.data_processing import *
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Create setup:

# %%
import os
os.makedirs("data/raw", exist_ok=True)
os.makedirs("data/clean", exist_ok=True)
os.makedirs("data/compressed", exist_ok=True)

# %% [markdown]
# # Data scraping from Wikipedia lists:

# %%
urls = [
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(0-9,_A-C)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(D-J)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(K-R)",
"https://en.wikipedia.org/wiki/List_of_fiction_works_made_into_feature_films_(S-Z)",
"http://en.wikipedia.org/wiki/List_of_short_fiction_made_into_feature_films",
"https://en.wikipedia.org/wiki/List_of_children%27s_books_made_into_feature_films",
#"https://en.wikipedia.org/wiki/List_of_films_based_on_comics"
]
df = scrape_wikipedia_list(urls)
df.columns=['book','author_book','film',"year_book", "year_film"]

df # fix later
# Out:
#                                  book         author_book  \
# 0                       The 25th Hour       David Benioff
# 1                         3 Assassins        Kōtarō Isaka
# 2                4.50 from Paddington     Agatha Christie
# 3                4.50 from Paddington     Agatha Christie
# 4                          58 Minutes        Walter Wager
# ...                               ...                 ...
# 5806                  Z for Zachariah   Robert C. O'Brien
# 5807                          Zathura  Chris Van Allsburg
# 5808  Zenon: Girl of the 21st Century      Marilyn Sadler
# 5809  Zenon: Girl of the 21st Century      Marilyn Sadler
# 5810  Zenon: Girl of the 21st Century      Marilyn Sadler
#
#                                  film year_book year_film
# 0                           25th Hour      2001      2002
# 1                         Grasshopper      2004      2015
# 2                    Murder, She Said      1957      1961
# 3               Crime Is Our Business      1957      2008
# 4                          Die Hard 2      1987      1990
# ...                               ...       ...       ...
# 5806                  Z for Zachariah      1974      2015
# 5807                          Zathura      2002      2005
# 5808  Zenon: Girl of the 21st Century      1997      1999
# 5809                Zenon: The Zequel      1997      2001
# 5810                        Zenon: Z3      1997      2003
#
# [5811 rows x 5 columns]

# %% [markdown]
# # Scraping tmdb data:

# %%
needed = False
if (needed==True): 
    data = {
    "book" : [],
    "author_book": [],
    "film" : [],
    "date_film" : [],
    "runtime" : [],
    "original_language":[],
    "votes_film" : [],
    "overview_film" : [],
    "vote_count_film" : [],
    "popularity_film" : [],
    "budget_film" : [],
    "revenue_film" : [],
    "genre_film" : [],
    "director" : [],
    "actor1" : [],
    "actor2" : [],
    "actor3" : []
}
    for i in tqdm(range(len(df))):
        n = df["film"][i]
        y = df["year_film"][i]
        k = tmdb_search_movie(n,year=y)
        if k is not None and "id" in list(k.keys()):
            k = tmdb_get_movie_details(k["id"])
        if k is not None:
            data["votes_film"].append(k["vote_average"])
            data["film"].append(k["original_title"])
            data["date_film"].append(k["release_date"])
            data["overview_film"].append(k["overview"])        
            data["vote_count_film"].append(k["vote_count"])
            data["popularity_film"].append(k["popularity"])
            data["genre_film"].append(k["genres"])
            data["original_language"].append(k["original_language"])
            data["runtime"].append(k["runtime"])
            direc = None
            if 'credits' in k and 'crew' in k['credits']:
                for person in k['credits']['crew']:
                    if person['job'] == 'Dcirector':
                        data["director"].append(person['name'])
                        direc = person['name']
                        break
            if direc is None:
                data['director'].append(np.nan)
            if 'credits' in k and 'cast' in k['credits']:
                for ii in range(min(3, len(k['credits']['cast']))):
                    data[f"actor{ii+1}"].append(k['credits']['cast'][ii]['name'])
                for ii in range(len(k['credits']['cast']), 3):
                    data[f"actor{ii+1}"].append(np.nan)
    
            if "budget" in list(k.keys()):
                data["budget_film"].append(k["budget"])
            else: 
                data["budget_film"].append(np.nan)
            if "revenue" in list(k.keys()): 
                data["revenue_film"].append(k["revenue"])
            else: 
                data["revenue_film"].append(np.nan)
        else: 
            data["votes_film"].append(np.nan)
            data["film"].append(n)
            data["date_film"].append(str(y))
            data["overview_film"].append(np.nan)
            data["vote_count_film"].append(np.nan)
            data["popularity_film"].append(np.nan)
            data["budget_film"].append(np.nan)
            data["revenue_film"].append(np.nan)
            data["genre_film"].append(np.nan)
            data["director"].append(np.nan)
            data["actor1"].append(np.nan)
            data["actor2"].append(np.nan)
            data["actor3"].append(np.nan)
            data["original_language"].append(np.nan)
            data["runtime"].append(np.nan)
        data["book"].append(df["book"][i])
        data["author_book"].append(df["author_book"][i])
    df = pd.DataFrame(data)
    df.to_csv("data/raw/movie_adaptation_list.csv")
    display(df)
else:
    df = pd.read_csv("data/raw/movie_adaptation_list.csv")
df
# Out:
#       Unnamed: 0                             book         author_book  \
# 0              0                    The 25th Hour       David Benioff
# 1              1                      3 Assassins        Kōtarō Isaka
# 2              2             4.50 from Paddington     Agatha Christie
# 3              3             4.50 from Paddington     Agatha Christie
# 4              4                       58 Minutes        Walter Wager
# ...          ...                              ...                 ...
# 5806        5806                  Z for Zachariah   Robert C. O'Brien
# 5807        5807                          Zathura  Chris Van Allsburg
# 5808        5808  Zenon: Girl of the 21st Century      Marilyn Sadler
# 5809        5809  Zenon: Girl of the 21st Century      Marilyn Sadler
# 5810        5810  Zenon: Girl of the 21st Century      Marilyn Sadler
#
#                                  film   date_film  runtime original_language  \
# 0                           25th Hour  2002-12-19    135.0                en
# 1                             グラスホッパー  2015-11-07    119.0                ja
# 2                     Murder She Said  1961-09-26     87.0                en
# 3          Le crime est notre affaire  2008-10-02    109.0                fr
# 4                          Die Hard 2  1990-07-03    124.0                en
# ...                               ...         ...      ...               ...
# 5806                  Z for Zachariah  2015-08-13     97.0                en
# 5807       Zathura: A Space Adventure  2005-11-06    101.0                en
# 5808  Zenon: Girl of the 21st Century  1999-01-23     97.0                en
# 5809                Zenon: The Zequel  2001-01-12     89.0                en
# 5810                        Zenon: Z3        2003      NaN               NaN
#
#       votes_film                                      overview_film  \
# 0          7.319  In New York City in the days following the eve...
# 1          5.929  Movie contains the stories of three people: Su...
# 2          7.328  Miss Marple believes she's seen a murder in a ...
# 3          5.883  Loosely based on "4.50 from Paddington" by Aga...
# 4          6.960  One year after his heroics in Los Angeles, Joh...
# ...          ...                                                ...
# 5806       5.687  In the wake of a nuclear war, a young woman su...
# 5807       6.429  After their father is called into work, two yo...
# 5808       6.070  Zenon Kar, a 13-year-old girl who lives on a s...
# 5809       5.601  Zenon Kar is 15 and lives on a space station w...
# 5810         NaN                                                NaN
#
#       vote_count_film  popularity_film  budget_film  revenue_film  \
# 0              2470.0           2.2401    5000000.0    23932055.0
# 1                14.0           1.4286          0.0           0.0
# 2               221.0           2.2798          0.0           0.0
# 3                94.0           3.0712   12000000.0           0.0
# 4              6145.0           7.5533   70000000.0   240031094.0
# ...               ...              ...          ...           ...
# 5806            969.0           1.1383          0.0      121461.0
# 5807           3449.0           7.2532   65000000.0    65079104.0
# 5808            186.0           2.3858          0.0           0.0
# 5809            109.0           5.0540          0.0           0.0
# 5810              NaN              NaN          NaN           NaN
#
#                                              genre_film  director  \
# 0     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...       NaN
# 1     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...       NaN
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       NaN
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       NaN
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...       NaN
# ...                                                 ...       ...
# 5806  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...       NaN
# 5807  [{'id': 878, 'name': 'Science Fiction'}, {'id'...       NaN
# 5808  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...       NaN
# 5809  [{'id': 10751, 'name': 'Family'}, {'id': 10770...       NaN
# 5810                                                NaN       NaN
#
#                    actor1                  actor2          actor3
# 0           Edward Norton  Philip Seymour Hoffman    Barry Pepper
# 1          Tadanobu Asano              Toma Ikuta  Ryosuke Yamada
# 2     Margaret Rutherford          Arthur Kennedy   Muriel Pavlow
# 3          Catherine Frot        André Dussollier     Claude Rich
# 4            Bruce Willis          Bonnie Bedelia  William Sadler
# ...                   ...                     ...             ...
# 5806        Margot Robbie        Chiwetel Ejiofor      Chris Pine
# 5807      Josh Hutcherson              Jonah Bobo     Dax Shepard
# 5808       Kirsten Storms            Raven-Symoné   Stuart Pankin
# 5809       Kirsten Storms          Shadia Simmons   Lauren Maltby
# 5810                  NaN                     NaN             NaN
#
# [5811 rows x 18 columns]

# %%
import json
df["book"] = df["book"].str.lower()
df2 = pd.read_csv("data/raw/booksummaries.csv",sep="\t")
df2.columns=["a1","a2","Book","Author","Year","Genre","Overview"]
df2 = df2.drop(columns=["a1","a2"])
df2["Book"] = df2["Book"].str.lower()
genres = []
for i in df2["Genre"]:
    if isinstance(i,str):
        genres.append(list(json.loads(i).values()))
    else:
        genres.append(np.nan)
df2["Genre"] = genres
overviews = []
genres = []
for i in df["book"]:
    overview = np.nan
    genre = np.nan
    if (df2["Book"] == i).any():
        overview = df2.loc[df2["Book"] == i, "Overview"].iloc[0]
        genre = df2.loc[df2["Book"] == i, "Genre"].iloc[0]
    overviews.append(overview)
    genres.append(genre)
df["overview_book"] = overviews
df["Genre_book"] = genres
df
# Out:
#       Unnamed: 0                             book         author_book  \
# 0              0                    the 25th hour       David Benioff
# 1              1                      3 assassins        Kōtarō Isaka
# 2              2             4.50 from paddington     Agatha Christie
# 3              3             4.50 from paddington     Agatha Christie
# 4              4                       58 minutes        Walter Wager
# ...          ...                              ...                 ...
# 5806        5806                  z for zachariah   Robert C. O'Brien
# 5807        5807                          zathura  Chris Van Allsburg
# 5808        5808  zenon: girl of the 21st century      Marilyn Sadler
# 5809        5809  zenon: girl of the 21st century      Marilyn Sadler
# 5810        5810  zenon: girl of the 21st century      Marilyn Sadler
#
#                                  film   date_film  runtime original_language  \
# 0                           25th Hour  2002-12-19    135.0                en
# 1                             グラスホッパー  2015-11-07    119.0                ja
# 2                     Murder She Said  1961-09-26     87.0                en
# 3          Le crime est notre affaire  2008-10-02    109.0                fr
# 4                          Die Hard 2  1990-07-03    124.0                en
# ...                               ...         ...      ...               ...
# 5806                  Z for Zachariah  2015-08-13     97.0                en
# 5807       Zathura: A Space Adventure  2005-11-06    101.0                en
# 5808  Zenon: Girl of the 21st Century  1999-01-23     97.0                en
# 5809                Zenon: The Zequel  2001-01-12     89.0                en
# 5810                        Zenon: Z3        2003      NaN               NaN
#
#       votes_film                                      overview_film  \
# 0          7.319  In New York City in the days following the eve...
# 1          5.929  Movie contains the stories of three people: Su...
# 2          7.328  Miss Marple believes she's seen a murder in a ...
# 3          5.883  Loosely based on "4.50 from Paddington" by Aga...
# 4          6.960  One year after his heroics in Los Angeles, Joh...
# ...          ...                                                ...
# 5806       5.687  In the wake of a nuclear war, a young woman su...
# 5807       6.429  After their father is called into work, two yo...
# 5808       6.070  Zenon Kar, a 13-year-old girl who lives on a s...
# 5809       5.601  Zenon Kar is 15 and lives on a space station w...
# 5810         NaN                                                NaN
#
#       vote_count_film  popularity_film  budget_film  revenue_film  \
# 0              2470.0           2.2401    5000000.0    23932055.0
# 1                14.0           1.4286          0.0           0.0
# 2               221.0           2.2798          0.0           0.0
# 3                94.0           3.0712   12000000.0           0.0
# 4              6145.0           7.5533   70000000.0   240031094.0
# ...               ...              ...          ...           ...
# 5806            969.0           1.1383          0.0      121461.0
# 5807           3449.0           7.2532   65000000.0    65079104.0
# 5808            186.0           2.3858          0.0           0.0
# 5809            109.0           5.0540          0.0           0.0
# 5810              NaN              NaN          NaN           NaN
#
#                                              genre_film  director  \
# 0     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...       NaN
# 1     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...       NaN
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       NaN
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       NaN
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...       NaN
# ...                                                 ...       ...
# 5806  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...       NaN
# 5807  [{'id': 878, 'name': 'Science Fiction'}, {'id'...       NaN
# 5808  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...       NaN
# 5809  [{'id': 10751, 'name': 'Family'}, {'id': 10770...       NaN
# 5810                                                NaN       NaN
#
#                    actor1                  actor2          actor3  \
# 0           Edward Norton  Philip Seymour Hoffman    Barry Pepper
# 1          Tadanobu Asano              Toma Ikuta  Ryosuke Yamada
# 2     Margaret Rutherford          Arthur Kennedy   Muriel Pavlow
# 3          Catherine Frot        André Dussollier     Claude Rich
# 4            Bruce Willis          Bonnie Bedelia  William Sadler
# ...                   ...                     ...             ...
# 5806        Margot Robbie        Chiwetel Ejiofor      Chris Pine
# 5807      Josh Hutcherson              Jonah Bobo     Dax Shepard
# 5808       Kirsten Storms            Raven-Symoné   Stuart Pankin
# 5809       Kirsten Storms          Shadia Simmons   Lauren Maltby
# 5810                  NaN                     NaN             NaN
#
#                                           overview_book  \
# 0      New York drug dealer Monty Brogan is arrested...
# 1                                                   NaN
# 2      Elspeth McGillicuddy has come from Scotland t...
# 3      Elspeth McGillicuddy has come from Scotland t...
# 4                                                   NaN
# ...                                                 ...
# 5806   Ann Burden's diary begins on Monday, May 20. ...
# 5807                                                NaN
# 5808                                                NaN
# 5809                                                NaN
# 5810                                                NaN
#
#                                              Genre_book
# 0                                             [Fiction]
# 1                                                   NaN
# 2     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 3     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 4                                                   NaN
# ...                                                 ...
# 5806  [Science Fiction, Speculative fiction, Childre...
# 5807                                                NaN
# 5808                                                NaN
# 5809                                                NaN
# 5810                                                NaN
#
# [5811 rows x 20 columns]

# %%
df2 = text_process_dataframe(df,["overview_film","overview_book"])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5811/5811 [04:43<00:00, 20.49it/s]
#  39%|█████████████████████████████▌                                              | 2256/5811 [16:08<3:12:14,  3.24s/it]

# %%
df2
# Out:
#       Unnamed: 0                             book         author_book  \
# 0              0                    the 25th hour       David Benioff
# 1              1                      3 assassins        Kōtarō Isaka
# 2              2             4.50 from paddington     Agatha Christie
# 3              3             4.50 from paddington     Agatha Christie
# 4              4                       58 minutes        Walter Wager
# ...          ...                              ...                 ...
# 5806        5806                  z for zachariah   Robert C. O'Brien
# 5807        5807                          zathura  Chris Van Allsburg
# 5808        5808  zenon: girl of the 21st century      Marilyn Sadler
# 5809        5809  zenon: girl of the 21st century      Marilyn Sadler
# 5810        5810  zenon: girl of the 21st century      Marilyn Sadler
#
#                                  film   date_film  runtime original_language  \
# 0                           25th Hour  2002-12-19    135.0                en
# 1                             グラスホッパー  2015-11-07    119.0                ja
# 2                     Murder She Said  1961-09-26     87.0                en
# 3          Le crime est notre affaire  2008-10-02    109.0                fr
# 4                          Die Hard 2  1990-07-03    124.0                en
# ...                               ...         ...      ...               ...
# 5806                  Z for Zachariah  2015-08-13     97.0                en
# 5807       Zathura: A Space Adventure  2005-11-06    101.0                en
# 5808  Zenon: Girl of the 21st Century  1999-01-23     97.0                en
# 5809                Zenon: The Zequel  2001-01-12     89.0                en
# 5810                        Zenon: Z3        2003      NaN               NaN
#
#       votes_film                                      overview_film  \
# 0          7.319  In New York City in the days following the eve...
# 1          5.929  Movie contains the stories of three people: Su...
# 2          7.328  Miss Marple believes she's seen a murder in a ...
# 3          5.883  Loosely based on "4.50 from Paddington" by Aga...
# 4          6.960  One year after his heroics in Los Angeles, Joh...
# ...          ...                                                ...
# 5806       5.687  In the wake of a nuclear war, a young woman su...
# 5807       6.429  After their father is called into work, two yo...
# 5808       6.070  Zenon Kar, a 13-year-old girl who lives on a s...
# 5809       5.601  Zenon Kar is 15 and lives on a space station w...
# 5810         NaN                                                NaN
#
#       vote_count_film  ...  revenue_film  \
# 0              2470.0  ...    23932055.0
# 1                14.0  ...           0.0
# 2               221.0  ...           0.0
# 3                94.0  ...           0.0
# 4              6145.0  ...   240031094.0
# ...               ...  ...           ...
# 5806            969.0  ...      121461.0
# 5807           3449.0  ...    65079104.0
# 5808            186.0  ...           0.0
# 5809            109.0  ...           0.0
# 5810              NaN  ...           NaN
#
#                                              genre_film  director  \
# 0     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...       NaN
# 1     [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...       NaN
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       NaN
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       NaN
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...       NaN
# ...                                                 ...       ...
# 5806  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...       NaN
# 5807  [{'id': 878, 'name': 'Science Fiction'}, {'id'...       NaN
# 5808  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...       NaN
# 5809  [{'id': 10751, 'name': 'Family'}, {'id': 10770...       NaN
# 5810                                                NaN       NaN
#
#                    actor1                  actor2          actor3  \
# 0           Edward Norton  Philip Seymour Hoffman    Barry Pepper
# 1          Tadanobu Asano              Toma Ikuta  Ryosuke Yamada
# 2     Margaret Rutherford          Arthur Kennedy   Muriel Pavlow
# 3          Catherine Frot        André Dussollier     Claude Rich
# 4            Bruce Willis          Bonnie Bedelia  William Sadler
# ...                   ...                     ...             ...
# 5806        Margot Robbie        Chiwetel Ejiofor      Chris Pine
# 5807      Josh Hutcherson              Jonah Bobo     Dax Shepard
# 5808       Kirsten Storms            Raven-Symoné   Stuart Pankin
# 5809       Kirsten Storms          Shadia Simmons   Lauren Maltby
# 5810                  NaN                     NaN             NaN
#
#                                           overview_book  \
# 0      New York drug dealer Monty Brogan is arrested...
# 1                                                   NaN
# 2      Elspeth McGillicuddy has come from Scotland t...
# 3      Elspeth McGillicuddy has come from Scotland t...
# 4                                                   NaN
# ...                                                 ...
# 5806   Ann Burden's diary begins on Monday, May 20. ...
# 5807                                                NaN
# 5808                                                NaN
# 5809                                                NaN
# 5810                                                NaN
#
#                                              Genre_book  \
# 0                                             [Fiction]
# 1                                                   NaN
# 2     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 3     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 4                                                   NaN
# ...                                                 ...
# 5806  [Science Fiction, Speculative fiction, Childre...
# 5807                                                NaN
# 5808                                                NaN
# 5809                                                NaN
# 5810                                                NaN
#
#                                   overview_film_encoded  \
# 0     [[0.013322022, -0.032403328, -0.07153424, -0.0...
# 1     [[-0.07211092, 0.023693504, -0.07063878, -0.05...
# 2     [[0.06292257, 8.667353e-05, 0.015638806, 0.046...
# 3     [[0.036849868, 0.03967552, 0.033876125, -0.032...
# 4     [[0.0013039461, -0.059566278, 0.018681584, -0....
# ...                                                 ...
# 5806  [[-0.004328058, -0.024808556, -0.00890559, 0.0...
# 5807  [[-0.051167563, 0.033402946, -0.060984835, -0....
# 5808  [[-0.06547429, 0.00043350196, -0.009626571, -0...
# 5809  [[-0.1401172, 0.021095766, -0.04444949, -0.062...
# 5810                                                NaN
#
#                                   overview_book_encoded
# 0     [[0.019042192, -0.03723496, -0.057174876, -0.0...
# 1                                                   NaN
# 2     [[0.022535434, -0.091755, 0.035180777, -0.0405...
# 3     [[0.022535434, -0.091755, 0.035180777, -0.0405...
# 4                                                   NaN
# ...                                                 ...
# 5806  [[-0.087789364, 0.018681446, 0.06705432, 0.026...
# 5807                                                NaN
# 5808                                                NaN
# 5809                                                NaN
# 5810                                                NaN
#
# [5811 rows x 22 columns]

# %%
count_nan_year = (df["date_film"].isnull()).sum().sum()
count_nan_director = (df["director"].isnull()).sum().sum()
count_nan_budget = (df["budget_film"] > 0).sum().sum()
count_nan_revenue = (df["revenue_film"] > 0).sum().sum()
count_nan_actor1 = (df["actor1"].isnull()).sum().sum()
count_nan_genre = (df["genre_film"].isnull()).sum().sum()
count_nan_genre_book = (df["Genre_book"].isnull()).sum().sum()
count_nan_lang = (df["original_language"].isnull()).sum().sum()
count_nan_pop = (df["popularity_film"].isnull()).sum().sum()
count_nan_nogenre = (df["Genre_book"].isnull() & df["genre_film"].isnull()).sum().sum()
count_nan_overview_film = (df["overview_film"].isnull()).sum().sum()
count_nan_overview_book = (df["overview_book"].isnull()).sum().sum()
count_nan_votecount = (df["vote_count_film"] <= 0 | df["vote_count_film"].isnull()).sum().sum()
count_nan_overview_filmandbook = (df["overview_book"].isnull() & df["overview_film"].isnull()).sum().sum()
print(f'{count_nan_year =}')
print(f'{count_nan_genre =}')
print(f'{count_nan_director =}')
print(f'{count_nan_revenue =}')
print(f'{count_nan_budget =}')
print(f'{count_nan_actor1 =}')
print(f'{count_nan_overview_film =}')
print(f'{count_nan_overview_book =}')
print(f'{count_nan_overview_filmandbook =}')
print(f"{count_nan_genre_book =}")
print(f"{count_nan_nogenre =}")
print(f"{count_nan_lang = }")
print(f"{count_nan_pop = }")
print(f"{count_nan_votecount = }")
# Out:
# count_nan_year =11
# count_nan_genre =520
# count_nan_director =5811
# count_nan_revenue =1795
# count_nan_budget =1802
# count_nan_actor1 =583
# count_nan_overview_film =558
# count_nan_overview_book =3332
# count_nan_overview_filmandbook =333
# count_nan_genre_book =3473
# count_nan_nogenre =325
# count_nan_lang = 520
# count_nan_pop = 520
# count_nan_votecount = 365

# %%
plt.hist(df["vote_count_film"],range =(0,1000))
plt.show()
plt.hist(df["vote_count_film"],range =(0,100))
plt.show()
print((df["vote_count_film"] < 10).sum().sum())
# Out:
# 1436

# %%
x = df["popularity_film"]
plt.hist(x,range=(x.min(), 50))
plt.show()

print(f"number of outliers for film popularity: {(x>x.mean() + 3*x.std()).sum().sum()}")
# Out:
# number of outliers for film popularity: 22

# %%
x = df["vote_count_film"]
plt.hist(x,range(0,10))
plt.show()

print(f"number of outliers for film popularity: {(x>x.mean() + 3*x.std()).sum().sum()}")
# Out:
# number of outliers for film popularity: 124

# %%
x = df["original_language"]
x.value_counts().plot(kind='bar', figsize=(13, 5), title='Counts of Original Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.show()

print("number of NaN: ",(x == np.nan).sum().sum())
print("not well presented languages: ")
print(x.value_counts()[x.value_counts() < 10])
# Out:
# number of NaN:  0
# not well presented languages:
# original_language
# cs    9
# ta    8
# pt    8
# ml    6
# no    6
# el    5
# fi    5
# ar    5
# hu    5
# te    4
# id    3
# kn    3
# fa    3
# bg    3
# et    3
# sh    2
# ur    1
# tl    1
# ca    1
# he    1
# mr    1
# lv    1
# sr    1
# uk    1
# Name: count, dtype: int64

# %%
x = df["votes_film"]
plt.hist(x)
plt.show()

# %%
x = df["runtime"]
plt.hist(x)
plt.show()

# %%
x = df["budget_film"].dropna()
x = x[x>0]

binwidth = 10000000
plt.hist(x,bins=np.arange(min(x), max(x) + binwidth, binwidth))
print(f"number of outliers for film budget: {(x>x.mean() + 3*x.std()).sum().sum()}")
# Out:
# number of outliers for film budget: 37

# %%
x = df["budget_film"].dropna()
x = x[x>0]
binwidth = 1000000

plt.hist(x,bins=np.arange(0,100000000 + binwidth, binwidth))
# Out:
# (array([198., 140.,  87.,  67.,  71.,  70.,  44.,  37.,  36.,  18.,  42.,
#          21.,  36.,  17.,  28.,  38.,  10.,  22.,  25.,  15.,  49.,   7.,
#          13.,   6.,  13.,  58.,   9.,  15.,   9.,   3.,  35.,   5.,  13.,
#           2.,   4.,  31.,   4.,   5.,  12.,   4.,  48.,   0.,   3.,   2.,
#           3.,  21.,   5.,   3.,   5.,   1.,  41.,   0.,   2.,   1.,   3.,
#          12.,   1.,   2.,   1.,   0.,  29.,   2.,   3.,   5.,   2.,   8.,
#           3.,   0.,   4.,   0.,  23.,   1.,   0.,   2.,   0.,  13.,   1.,
#           0.,   3.,   4.,  18.,   0.,   2.,   0.,   0.,   8.,   0.,   2.,
#           0.,   0.,  15.,   0.,   0.,   3.,   1.,   4.,   0.,   0.,   0.,
#          23.]),
#  array([0.0e+00, 1.0e+06, 2.0e+06, 3.0e+06, 4.0e+06, 5.0e+06, 6.0e+06,
#         7.0e+06, 8.0e+06, 9.0e+06, 1.0e+07, 1.1e+07, 1.2e+07, 1.3e+07,
#         1.4e+07, 1.5e+07, 1.6e+07, 1.7e+07, 1.8e+07, 1.9e+07, 2.0e+07,
#         2.1e+07, 2.2e+07, 2.3e+07, 2.4e+07, 2.5e+07, 2.6e+07, 2.7e+07,
#         2.8e+07, 2.9e+07, 3.0e+07, 3.1e+07, 3.2e+07, 3.3e+07, 3.4e+07,
#         3.5e+07, 3.6e+07, 3.7e+07, 3.8e+07, 3.9e+07, 4.0e+07, 4.1e+07,
#         4.2e+07, 4.3e+07, 4.4e+07, 4.5e+07, 4.6e+07, 4.7e+07, 4.8e+07,
#         4.9e+07, 5.0e+07, 5.1e+07, 5.2e+07, 5.3e+07, 5.4e+07, 5.5e+07,
#         5.6e+07, 5.7e+07, 5.8e+07, 5.9e+07, 6.0e+07, 6.1e+07, 6.2e+07,
#         6.3e+07, 6.4e+07, 6.5e+07, 6.6e+07, 6.7e+07, 6.8e+07, 6.9e+07,
#         7.0e+07, 7.1e+07, 7.2e+07, 7.3e+07, 7.4e+07, 7.5e+07, 7.6e+07,
#         7.7e+07, 7.8e+07, 7.9e+07, 8.0e+07, 8.1e+07, 8.2e+07, 8.3e+07,
#         8.4e+07, 8.5e+07, 8.6e+07, 8.7e+07, 8.8e+07, 8.9e+07, 9.0e+07,
#         9.1e+07, 9.2e+07, 9.3e+07, 9.4e+07, 9.5e+07, 9.6e+07, 9.7e+07,
#         9.8e+07, 9.9e+07, 1.0e+08]),
#  <BarContainer object of 100 artists>)

# %%
x = df["revenue_film"].dropna()
x = x[x>0]

binwidth = 10000000
plt.hist(x,bins=np.arange(min(x), max(x) + binwidth, binwidth))
print(f"number of outliers for film revenue: {(x>x.mean() + 3*x.std()).sum().sum()}")
# Out:
# number of outliers for film revenue: 58

# %%
x = df["revenue_film"].dropna()
binwidth = 1000000
x = x[x>0]

plt.hist(x,bins=np.arange(0,100000000 + binwidth, binwidth))
# Out:
# (array([153.,  81.,  70.,  64.,  39.,  35.,  42.,  36.,  34.,  24.,  36.,
#          23.,  32.,  26.,  25.,  27.,  15.,  20.,   6.,  11.,  20.,  22.,
#          25.,  13.,  11.,  10.,   7.,  13.,  13.,  15.,  14.,  10.,  15.,
#          16.,  16.,  10.,  10.,   9.,   9.,   8.,  12.,   8.,  16.,   9.,
#           4.,   6.,   4.,   9.,   3.,   6.,   6.,   3.,   6.,   0.,   1.,
#           6.,   1.,   9.,   2.,   2.,   8.,   5.,   4.,   6.,   0.,   3.,
#           4.,   2.,   5.,   3.,   2.,   6.,   5.,   1.,   5.,   7.,  11.,
#           3.,   4.,   2.,   2.,   3.,   4.,   0.,   4.,   5.,   2.,   9.,
#           1.,   2.,   1.,   2.,   3.,   5.,   2.,   3.,   1.,   1.,   1.,
#           2.]),
#  array([0.0e+00, 1.0e+06, 2.0e+06, 3.0e+06, 4.0e+06, 5.0e+06, 6.0e+06,
#         7.0e+06, 8.0e+06, 9.0e+06, 1.0e+07, 1.1e+07, 1.2e+07, 1.3e+07,
#         1.4e+07, 1.5e+07, 1.6e+07, 1.7e+07, 1.8e+07, 1.9e+07, 2.0e+07,
#         2.1e+07, 2.2e+07, 2.3e+07, 2.4e+07, 2.5e+07, 2.6e+07, 2.7e+07,
#         2.8e+07, 2.9e+07, 3.0e+07, 3.1e+07, 3.2e+07, 3.3e+07, 3.4e+07,
#         3.5e+07, 3.6e+07, 3.7e+07, 3.8e+07, 3.9e+07, 4.0e+07, 4.1e+07,
#         4.2e+07, 4.3e+07, 4.4e+07, 4.5e+07, 4.6e+07, 4.7e+07, 4.8e+07,
#         4.9e+07, 5.0e+07, 5.1e+07, 5.2e+07, 5.3e+07, 5.4e+07, 5.5e+07,
#         5.6e+07, 5.7e+07, 5.8e+07, 5.9e+07, 6.0e+07, 6.1e+07, 6.2e+07,
#         6.3e+07, 6.4e+07, 6.5e+07, 6.6e+07, 6.7e+07, 6.8e+07, 6.9e+07,
#         7.0e+07, 7.1e+07, 7.2e+07, 7.3e+07, 7.4e+07, 7.5e+07, 7.6e+07,
#         7.7e+07, 7.8e+07, 7.9e+07, 8.0e+07, 8.1e+07, 8.2e+07, 8.3e+07,
#         8.4e+07, 8.5e+07, 8.6e+07, 8.7e+07, 8.8e+07, 8.9e+07, 9.0e+07,
#         9.1e+07, 9.2e+07, 9.3e+07, 9.4e+07, 9.5e+07, 9.6e+07, 9.7e+07,
#         9.8e+07, 9.9e+07, 1.0e+08]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# ## Adding information with the Film Dataset (UMDBS)

# %%
## === 1.  Relations list for films
relations_film_dbpedia = get_relations("data/raw/film.dbpedia.graph")
relations_film_yago = get_relations("data/raw/film.yago.graph")

dict_films_imdb = get_film_imdb("data/raw/film.imdb.json")

# %%
## === 2. Check useful roles to merge with our current dataset and replace missing values

# %%
get_roles(relations_film_dbpedia)
# Out:
# ['Work/runtime',
#  'abstract',
#  'album',
#  'artist',
#  'associatedAct',
#  'associatedBand',
#  'associatedMusicalArtist',
#  'author',
#  'award',
#  'bandMember',
#  'basedOn',
#  'battle',
#  'billed',
#  'binomialAuthority',
#  'birthPlace',
#  'brand',
#  'broadcastNetwork',
#  'budget',
#  'campus',
#  'channel',
#  'child',
#  'cinematography',
#  'city',
#  'closingFilm',
#  'coach',
#  'company',
#  'completionDate',
#  'composer',
#  'country',
#  'coverArtist',
#  'creativeDirector',
#  'creator',
#  'currentMember',
#  'currentProduction',
#  'dam',
#  'deathPlace',
#  'debutTeam',
#  'developer',
#  'director',
#  'distributor',
#  'editing',
#  'editor',
#  'employer',
#  'endingTheme',
#  'executiveProducer',
#  'film',
#  'followingEvent',
#  'format',
#  'formerBandMember',
#  'formerBroadcastNetwork',
#  'gender',
#  'genre',
#  'genus',
#  'governmentType',
#  'grandsire',
#  'gross',
#  'guest',
#  'head',
#  'hometown',
#  'ideology',
#  'industry',
#  'inflow',
#  'influenced',
#  'influencedBy',
#  'isPartOf',
#  'isPartOfMilitaryConflict',
#  'keyPerson',
#  'knownFor',
#  'language',
#  'lastAppearance',
#  'leaderName',
#  'license',
#  'literaryGenre',
#  'location',
#  'locationCountry',
#  'manager',
#  'march',
#  'militaryUnit',
#  'musicComposer',
#  'musicalArtist',
#  'musicalBand',
#  'narrator',
#  'nationality',
#  'network',
#  'nonFictionSubject',
#  'notableWork',
#  'numberOfEpisodes',
#  'numberOfSeasons',
#  'occupation',
#  'openingFilm',
#  'openingTheme',
#  'parent',
#  'part',
#  'partner',
#  'person',
#  'photographer',
#  'picture',
#  'place',
#  'portrayer',
#  'position',
#  'presenter',
#  'previousEvent',
#  'previousWork',
#  'producer',
#  'product',
#  'profession',
#  'programmeFormat',
#  'publisher',
#  'race',
#  'recordLabel',
#  'recordedIn',
#  'region',
#  'related',
#  'relative',
#  'releaseDate',
#  'routeEnd',
#  'routeJunction',
#  'runtime',
#  'sales',
#  'series',
#  'show',
#  'showJudge',
#  'significantProject',
#  'sisterStation',
#  'species',
#  'spouse',
#  'starring',
#  'storyEditor',
#  'subject',
#  'subsequentWork',
#  'subsidiary',
#  'successor',
#  'team',
#  'televisionSeries',
#  'tenant',
#  'trainer',
#  'tvComId',
#  'type',
#  'voice',
#  'writer']

# %%
get_roles(relations_film_yago)
# Out:
# ['actedIn',
#  'created',
#  'directed',
#  'edited',
#  'happenedIn',
#  'hasDuration',
#  'hasImdb',
#  'hasLatitude',
#  'hasLongitude',
#  'hasPages',
#  'isLocatedIn',
#  'owns',
#  'wroteMusicFor']

# %%
dict_films_imdb[0].keys()
# Out:
# dict_keys(['Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards', 'Poster', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'Response'])

# %%
# -- extend our dataset with the three sources (adding awards, get missing value)
ex_df= extend_df(df, relations_film_dbpedia, relations_film_yago, dict_films_imdb)
# Out:
# extend film df: 100%|████████████████████████████████████████████████████████████| 5811/5811 [00:02<00:00, 2402.79it/s]

# %%
ex_df
# Out:
#       Unnamed: 0                             book         author_book  \
# 0              0                    the 25th hour       David Benioff
# 1              1                      3 assassins        Kōtarō Isaka
# 2              2             4.50 from paddington     Agatha Christie
# 3              3             4.50 from paddington     Agatha Christie
# 4              4                       58 minutes        Walter Wager
# ...          ...                              ...                 ...
# 5806        5806                  z for zachariah   Robert C. O'Brien
# 5807        5807                          zathura  Chris Van Allsburg
# 5808        5808  zenon: girl of the 21st century      Marilyn Sadler
# 5809        5809  zenon: girl of the 21st century      Marilyn Sadler
# 5810        5810  zenon: girl of the 21st century      Marilyn Sadler
#
#                                  film   date_film runtime original_language  \
# 0                           25th Hour  2002-12-19   135.0                en
# 1                             グラスホッパー  2015-11-07   119.0                ja
# 2                     Murder She Said  1961-09-26    87.0                en
# 3          Le crime est notre affaire  2008-10-02   109.0                fr
# 4                          Die Hard 2  1990-07-03   124.0                en
# ...                               ...         ...     ...               ...
# 5806                  Z for Zachariah  2015-08-13    97.0                en
# 5807       Zathura: A Space Adventure  2005-11-06   101.0                en
# 5808  Zenon: Girl of the 21st Century  1999-01-23    97.0                en
# 5809                Zenon: The Zequel  2001-01-12    89.0                en
# 5810                        Zenon: Z3        2003  81 min           English
#
#      votes_film                                      overview_film  \
# 0         7.319  In New York City in the days following the eve...
# 1         5.929  Movie contains the stories of three people: Su...
# 2         7.328  Miss Marple believes she's seen a murder in a ...
# 3         5.883  Loosely based on "4.50 from Paddington" by Aga...
# 4          6.96  One year after his heroics in Los Angeles, Joh...
# ...         ...                                                ...
# 5806      5.687  In the wake of a nuclear war, a young woman su...
# 5807      6.429  After their father is called into work, two yo...
# 5808       6.07  Zenon Kar, a 13-year-old girl who lives on a s...
# 5809      5.601  Zenon Kar is 15 and lives on a space station w...
# 5810      1,800  In the third installment of the hit Zenon tril...
#
#      vote_count_film  ...                                         genre_film  \
# 0             2470.0  ...  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 1               14.0  ...  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 2              221.0  ...  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 3               94.0  ...  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 4             6145.0  ...  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...              ...  ...                                                ...
# 5806           969.0  ...  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 5807          3449.0  ...  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 5808           186.0  ...  [{'id': 10751, 'name': 'Family'}, {'id': 12, '...
# 5809           109.0  ...  [{'id': 10751, 'name': 'Family'}, {'id': 10770...
# 5810           1,800  ...                          Adventure, Comedy, Family
#
#              director               actor1                  actor2  \
# 0           Spike Lee        Edward Norton  Philip Seymour Hoffman
# 1                 NaN       Tadanobu Asano              Toma Ikuta
# 2      George Pollock  Margaret Rutherford          Arthur Kennedy
# 3       Pascal_Thomas       Catherine Frot        André Dussollier
# 4        Renny Harlin         Bruce Willis          Bonnie Bedelia
# ...               ...                  ...                     ...
# 5806      Craig Zobel        Margot Robbie        Chiwetel Ejiofor
# 5807      Jon Favreau      Josh Hutcherson              Jonah Bobo
# 5808  Kenneth Johnson       Kirsten Storms            Raven-Symoné
# 5809       Manny Coto       Kirsten Storms          Shadia Simmons
# 5810       Steve Rash       Kirsten Storms           Lauren Maltby
#
#               actor3                                      overview_book  \
# 0       Barry Pepper   New York drug dealer Monty Brogan is arrested...
# 1     Ryosuke Yamada                                                NaN
# 2      Muriel Pavlow   Elspeth McGillicuddy has come from Scotland t...
# 3        Claude Rich   Elspeth McGillicuddy has come from Scotland t...
# 4     William Sadler                                                NaN
# ...              ...                                                ...
# 5806      Chris Pine   Ann Burden's diary begins on Monday, May 20. ...
# 5807     Dax Shepard                                                NaN
# 5808   Stuart Pankin                                                NaN
# 5809   Lauren Maltby                                                NaN
# 5810   Alyson Morgan                                                NaN
#
#                                              Genre_book  \
# 0                                             [Fiction]
# 1                                                   NaN
# 2     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 3     [Cozy, Mystery, Crime Fiction, Fiction, Suspense]
# 4                                                   NaN
# ...                                                 ...
# 5806  [Science Fiction, Speculative fiction, Childre...
# 5807                                                NaN
# 5808                                                NaN
# 5809                                                NaN
# 5810                                                NaN
#
#                            norm_title film_year  \
# 0                           25th_hour    2002.0
# 1                             グラスホッパー    2015.0
# 2                     murder_she_said    1961.0
# 3          le_crime_est_notre_affaire    2008.0
# 4                          die_hard_2    1990.0
# ...                               ...       ...
# 5806                  z_for_zachariah    2015.0
# 5807       zathura:_a_space_adventure    2005.0
# 5808  zenon:_girl_of_the_21st_century    1999.0
# 5809                zenon:_the_zequel    2001.0
# 5810                        zenon:_z3    2003.0
#
#                                                  awards
# 0     Nominated for 1 Golden Globe. Another 4 wins &...
# 1                                                   NaN
# 2                                                   N/A
# 3                                                   NaN
# 4                                 1 win & 1 nomination.
# ...                                                 ...
# 5806                                     3 nominations.
# 5807                            2 wins & 3 nominations.
# 5808                                     2 nominations.
# 5809                                      1 nomination.
# 5810                                                N/A
#
# [5811 rows x 23 columns]

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0              0
# book                    0
# author_book            26
# film                    0
# date_film              11
# runtime               520
# original_language     520
# votes_film            520
# overview_film         558
# vote_count_film       520
# popularity_film       520
# budget_film           520
# revenue_film          520
# genre_film            520
# director             5811
# actor1                583
# actor2                602
# actor3                625
# overview_book        3332
# Genre_book           3473
# norm_title              0
# film_year              17
# dtype: int64

# %%
print(ex_df.isnull().sum())
# Out:
# Unnamed: 0              0
# book                    0
# author_book            26
# film                    0
# date_film              11
# runtime               277
# original_language     290
# votes_film            295
# overview_film         325
# vote_count_film       295
# popularity_film       520
# budget_film           503
# revenue_film          502
# genre_film            295
# director             1781
# actor1                314
# actor2                348
# actor3                374
# overview_book        3332
# Genre_book           3473
# norm_title              0
# film_year              17
# awards               1902
# dtype: int64
