# %% [markdown]
# # Books to Movie adaptation
# ----

# %% [markdown]
# ## Liens utiles
#
# - Pour avoir les infos sur les films (API TMDB) : https://developer.themoviedb.org/reference/movie-details

# %% [markdown]
# # 1 - Récupération des films + Infos sur TMDB (environ 7000 films)

# %%
import requests 
import pandas as pd  
import time  
from tqdm import tqdm  
import numpy as np

# %% [markdown]
# **Memento**:
# - genres (id/name)
# - imdb_id
# - original_title (just in case for the wiki)
# - release_date
# - runtime
# - title
# - {"id": 818, "name": "based on novel"}
# - https://m.imdb.com/fr/search/title/?keywords=based-on-novel&explore=keywords (35K mais way too much non?)
# - A rajouter les nominations si possible https://www.omdbapi.com/ ou a scrapper si besoin

# %%
## ======= 1 - Récupération des adaptations de livres + Données disponibles avec TMBD ========== ##

def get_movie_dataset():
    
    
    all_movies = []

    # 1 - Récupération de tous les films basés sur des livres
    movie_ids = []
    url = "https://api.themoviedb.org/3/discover/movie"
    params = {
        'api_key': API_KEY,
        'with_keywords': '818',
        'page': 1
    }
    response = requests.get(url, params=params)
    data = response.json()
    total_pages = data.get('total_pages', 500)  
    total_results = data.get('total_results', 0)
    
    
    for page in tqdm(range(1, total_pages + 1), desc="Page"):
        url = "https://api.themoviedb.org/3/discover/movie"
        params = {
            'api_key': API_KEY,
            'with_keywords': '818',  
            'page': page
        }
        response = requests.get(url, params=params)
        data = response.json()
        
        for movie in data['results']:
            movie_ids.append(movie['id'])
        
        time.sleep(0.25)
    
    # 2 - Pour chaque film, récupérations des infos
    for movie_id in tqdm(movie_ids, desc="Movies"):
        
        
        url = f"https://api.themoviedb.org/3/movie/{movie_id}"
        params = {
            'api_key': API_KEY,
            'append_to_response': 'credits,keywords' # keywords pour l'instant, à retirer si pas trop utile finalement
        }
        response = requests.get(url, params=params)
        details = response.json()

        
        # Crew -> df séparé?
        director = None
        if 'credits' in details and 'crew' in details['credits']:
            for person in details['credits']['crew']:
                if person['job'] == 'Director':
                    director = person['name']
                    break
        actors = [None, None, None]
        if 'credits' in details and 'cast' in details['credits']:
            for i in range(min(3, len(details['credits']['cast']))):
                actors[i] = details['credits']['cast'][i]['name']
        
        
        genres = ', '.join([g['name'] for g in details.get('genres', [])])
        
        keywords_list = []
        if 'keywords' in details and 'keywords' in details['keywords']:
            for kw in details['keywords']['keywords']:
                keywords_list.append(kw['name'])
        keywords = ', '.join(keywords_list)
        
        release_date = details.get('release_date', '')
        year = release_date[:4] if release_date else None
        
        
        movie_data = {
            'tmdb_id': details.get('id'),
            'imdb_id': details.get('imdb_id'),
            'title': details.get('title'),
            'original_title': details.get('original_title'),
            'release_date': release_date,
            'year': year,
            'runtime': details.get('runtime'),
            'budget': details.get('budget', None),
            'revenue': details.get('revenue', None),
            'vote_average': details.get('vote_average', None),
            'vote_count': details.get('vote_count', None),
            'popularity': details.get('popularity', None),
            'director': director,
            'actor_1': actors[0],
            'actor_2': actors[1],
            'actor_3': actors[2],
            'genres': genres,
            'keywords': keywords, 
            'overview': details.get('overview', ''), #résumé du plot mais peut etre pas utile 
            'original_language': details.get('original_language'),
        }
        
        all_movies.append(movie_data)
        
        time.sleep(0.3)
    
    movies_dataset = pd.DataFrame(all_movies).fillna('')
    
    return movies_dataset

# %%
movies_df = get_movie_dataset()
# Out:
# Page: 100%|██████████████████████████████████████████████████████████████████████████| 379/379 [01:41<00:00,  3.72it/s]
# Movies: 100%|██████████████████████████████████████████████████████████████████████| 7564/7564 [51:33<00:00,  2.45it/s]

# %%
# Peut-être comparé les meilleures adaptation selon les pays
print(movies_df[movies_df['original_language'] == 'fr'])
# Out:
#       tmdb_id     imdb_id                                              title  \
# 16      15383   tt0064040                                    Army of Shadows
# 151   1084736  tt26446278                          The Count of Monte Cristo
# 194     65496   tt1570970                                   Student Services
# 208       266   tt0057345                                           Contempt
# 259      4561   tt0073115                                     The Story of O
# ...       ...         ...                                                ...
# 7457   862095                                             The Hands of Orlac
# 7460   858532   tt0897388  Silence de Septembre (Chapitre 2) ou Quelques ...
# 7470  1279542                  Sherlock Holmes et l'Aventure du Diamant Bleu
# 7527  1440658  tt35933265                       When You Listen to This Song
# 7539   989955  tt18378400                           Les raisins de la misère
#
#                                          original_title release_date  year  \
# 16                                   L'Armée des ombres   1969-09-10  1969
# 151                            Le Comte de Monte-Cristo   2024-06-28  2024
# 194                                   Mes chères études   2010-01-18  2010
# 208                                           Le Mépris   1963-10-29  1963
# 259                                        Histoire d'O   1975-08-27  1975
# ...                                                 ...          ...   ...
# 7457                                  Les Mains d'Orlac
# 7460  Silence de Septembre (Chapitre 2) ou Quelques ...   2005-01-25  2005
# 7470      Sherlock Holmes et l'Aventure du Diamant Bleu   2023-01-01  2023
# 7527                   Quand tu écouteras cette chanson   2025-03-04  2025
# 7539                           Les raisins de la misère   2021-10-14  2021
#
#       runtime    budget   revenue  vote_average  vote_count  popularity  \
# 16        145         0    906133         7.900         698     53.6108
# 151       178  46000000  75360860         8.000        1801     10.7738
# 194       101         0         0         5.300         135      7.9345
# 208       103    900000    528428         7.064         894      9.1984
# 259        97         0         0         5.500         168      7.2877
# ...       ...       ...       ...           ...         ...         ...
# 7457        0         0         0         0.000           0      0.0911
# 7460        0         0         0         0.000           0      0.0722
# 7470       80         0         0         6.000           1      0.1523
# 7527       54         0         0         8.000           1      0.0362
# 7539       55         0         0         0.000           0      0.0386
#
#                         director            actor_1           actor_2  \
# 16          Jean-Pierre Melville       Lino Ventura     Paul Meurisse
# 151   Alexandre de La Patellière       Pierre Niney  Bastien Bouillon
# 194            Emmanuelle Bercot   Déborah François      Mathieu Demy
# 208              Jean-Luc Godard    Brigitte Bardot    Michel Piccoli
# 259                 Just Jaeckin      Corinne Cléry          Udo Kier
# ...                          ...                ...               ...
# 7457           Dominique Baumard     Melvil Poupaud
# 7460    dcpa.Christophe-Philippe     Maurice Aufair       Dan Queroub
# 7470           Christophe Delort  Christophe Delort        Henri Rizk
# 7527                Mona Achache         Lola Lafon
# 7539            Ixchel Delaporte
#
#                     actor_3                    genres  \
# 16       Jean-Pierre Cassel      War, Drama, Thriller
# 151        Anaïs Demoustier  Adventure, Action, Drama
# 194            Alain Cauchi                     Drama
# 208            Jack Palance            Drama, Romance
# 259             Alain Noury                     Drama
# ...                     ...                       ...
# 7457                                Thriller, Fantasy
# 7460  Marie-Claire Dewarrat                     Drama
# 7470       Benedicte Bourel           Mystery, Comedy
# 7527                             Documentary, History
# 7539                                      Documentary
#
#                                                keywords  \
# 16    czech, paris, france, based on novel or book, ...
# 151   based on novel or book, count, revenge, wrongf...
# 194   hotel, hotel room, jealousy, france, based on ...
# 208   jealousy, based on novel or book, villa, love ...
# 259   bondage, based on novel or book, eroticism, sa...
# ...                                                 ...
# 7457                             based on novel or book
# 7460  based on novel or book, switzerland, love, dea...
# 7470  based on novel or book, investigation, theater...
# 7527  based on novel or book, museum, anne frank, do...
# 7539  based on novel or book, economy, insecurity, w...
#
#                                                overview original_language
# 16    Betrayed by an informant, Philippe Gerbier fin...                fr
# 151   Edmond Dantes becomes the target of a sinister...                fr
# 194   Nineteen-year-old Laura is stressed by her fir...                fr
# 208   A philistine in the art film business, Jeremy ...                fr
# 259   The beautiful O is taken by her boyfriend, Ren...                fr
# ...                                                 ...               ...
# 7457        Film based on the novel The Hands of Orlac.                fr
# 7460  Second chapter of a trilogy of short films abo...                fr
# 7470  Sherlock and Doctor Watson are back and invest...                fr
# 7527  In August 2021, writer Lola Lafon spent a nigh...                fr
# 7539  Famous worldwide for its great wines, the Bord...                fr
#
# [391 rows x 20 columns]

# %%
---
##### PB ->  il y a des films avec des auteurs étranges... Peut-être les filtrer
*/!\ Attention prévoir mini une heure pour chaque version !*

# %%
#========== VERSION 2 - Uniquement avec les novels explicitement ecrit (environ 6000) =========== #

def get_movie_novel():
    
    
    all_movies = []
    movie_ids = []
    url = "https://api.themoviedb.org/3/discover/movie"
    params = {
        'api_key': API_KEY,
        'with_keywords': '818',
        'page': 1
    }
    response = requests.get(url, params=params)
    data = response.json()
    total_pages = data.get('total_pages', 500)
    total_results = data.get('total_results', 0)
    
    
    for page in tqdm(range(1, total_pages + 1), desc="Page"):
        url = "https://api.themoviedb.org/3/discover/movie"
        params = {
            'api_key': API_KEY,
            'with_keywords': '818',  
            'page': page
        }
        response = requests.get(url, params=params)
        data = response.json()
        
        for movie in data['results']:
            movie_id = movie['id']
            url_details = f"https://api.themoviedb.org/3/movie/{movie_id}"
            params_details = {
                'api_key': API_KEY,
                'append_to_response': 'credits'
            }
            response_details = requests.get(url_details, params=params_details)
            details = response_details.json()
            
            novel_author = None
            if 'credits' in details and 'crew' in details['credits']:
                for person in details['credits']['crew']:
                    if person.get('job') == 'Novel':
                        novel_author = person.get('name')
                        break
            if novel_author:
                movie_ids.append(movie_id)
        
        time.sleep(0.25)
    
    for movie_id in tqdm(movie_ids, desc="Movies"):
        
        
        url = f"https://api.themoviedb.org/3/movie/{movie_id}"
        params = {
            'api_key': API_KEY,
            'append_to_response': 'credits,keywords'
        }
        response = requests.get(url, params=params)
        details = response.json()

        novel_author = None
        if 'credits' in details and 'crew' in details['credits']:
            for person in details['credits']['crew']:
                if person.get('job') == 'Novel':
                    novel_author = person.get('name')
                    break

        director = None
        if 'credits' in details and 'crew' in details['credits']:
            for person in details['credits']['crew']:
                if person['job'] == 'Director':
                    director = person['name']
                    break
        actors = [None, None, None]
        if 'credits' in details and 'cast' in details['credits']:
            for i in range(min(3, len(details['credits']['cast']))):
                actors[i] = details['credits']['cast'][i]['name']
        
        
        genres = ', '.join([g['name'] for g in details.get('genres', [])])
        
        keywords_list = []
        if 'keywords' in details and 'keywords' in details['keywords']:
            for kw in details['keywords']['keywords']:
                keywords_list.append(kw['name'])
        keywords = ', '.join(keywords_list)
        
        release_date = details.get('release_date', '')
        year = release_date[:4] if release_date else None
        
        
        movie_data = {
            'tmdb_id': details.get('id'),
            'imdb_id': details.get('imdb_id'),
            'title': details.get('title'),
            'original_title': details.get('original_title'),
            'release_date': release_date,
            'year': year,
            'runtime': details.get('runtime'),
            'budget': details.get('budget', None),
            'revenue': details.get('revenue', None),
            'vote_average': details.get('vote_average', None),
            'vote_count': details.get('vote_count', None),
            'popularity': details.get('popularity', None),
            'director': director,
            'author': novel_author,
            'actor_1': actors[0],
            'actor_2': actors[1],
            'actor_3': actors[2],
            'genres': genres,
            'keywords': keywords, 
            'overview': details.get('overview', ''),
            'original_language': details.get('original_language'),
        }
        
        all_movies.append(movie_data)
        
        time.sleep(0.3)
    
    movies_dataset = pd.DataFrame(all_movies).fillna('')
    
    return movies_dataset

# %%
movies_novel_dataset =  get_movie_novel()
# Out:
# Page: 100%|██████████████████████████████████████████████████████████████████████████| 379/379 [16:38<00:00,  2.63s/it]
# Movies: 100%|██████████████████████████████████████████████████████████████████████| 5676/5676 [35:10<00:00,  2.69it/s]

# %%
# 2 - Relier avec les oeuvres originales (ISBN si possible)

# %%
print(movies_novel_dataset)
# Out:
#       tmdb_id     imdb_id                         title  \
# 0     1156594  tt33311244                     Our Fault
# 1      604079  tt10374610                 The Long Walk
# 2     1272166  tt32063098      Ballad of a Small Player
# 3     1327862  tt33088452                Regretting You
# 4     1062722   tt1312221                  Frankenstein
# ...       ...         ...                           ...
# 5671  1532630  tt37967616            All in Monte Carlo
# 5672  1507429                         What You Do to Me
# 5673  1572308  tt30139424          Trampoty pana Humbla
# 5674   768226   tt1235191                    Zpovědnice
# 5675   470948   tt0132161  The Victims of the East Wind
#
#                     original_title release_date  year  runtime     budget  \
# 0                    Culpa nuestra   2025-10-15  2025      112          0
# 1                    The Long Walk   2025-09-10  2025      108   20000000
# 2         Ballad of a Small Player   2025-10-15  2025      101          0
# 3                   Regretting You   2025-10-22  2025      116   30000000
# 4                     Frankenstein   2025-10-17  2025      150  120000000
# ...                            ...          ...   ...      ...        ...
# 5671            All in Monte Carlo                           0          0
# 5672             What You Do to Me                           0          0
# 5673          Trampoty pana Humbla   1998-03-25  1998        0          0
# 5674                    Zpovědnice   1929-04-12  1929        0          0
# 5675  Os Flagelados do Vento Leste   1987-01-01  1987       91          0
#
#        revenue  vote_average  ...  popularity            director  \
# 0            0         7.573  ...    228.5306    Domingo González
# 1     54054069         7.000  ...    140.4097    Francis Lawrence
# 2            0         6.300  ...    103.0593       Edward Berger
# 3            0         7.100  ...     82.6904          Josh Boone
# 4            0         7.900  ...     71.5784  Guillermo del Toro
# ...        ...           ...  ...         ...                 ...
# 5671         0         0.000  ...      0.0214
# 5672         0         0.000  ...      0.0193
# 5673         0         0.000  ...      0.0143      Viktor Polesný
# 5674         0         0.000  ...      0.0143       Norbert Mašek
# 5675         0         0.000  ...      0.0000       António Faria
#
#                   author            actor_1                 actor_2  \
# 0           Mercedes Ron     Nicole Wallace         Gabriel Guevara
# 1           Stephen King     Cooper Hoffman           David Jonsson
# 2       Lawrence Osborne      Colin Farrell               Fala Chen
# 3         Colleen Hoover      Mckenna Grace        Allison Williams
# 4           Mary Shelley        Oscar Isaac            Jacob Elordi
# ...                  ...                ...                     ...
# 5671       Anna Shilling
# 5672  Rochelle Weinstein
# 5673       Vladimír Neff   Miroslav Donutil          Jiří Langmajer
# 5674   Christian Winther          Pavel Rón        Isida Pruszińská
# 5675        Manuel Lopes  Eliana Lima-Nanni  Maria da Luz Rodrigues
#
#                actor_3                             genres  \
# 0     Gabriela Andrada                     Romance, Drama
# 1      Garrett Wareing  Thriller, Horror, Science Fiction
# 2        Tilda Swinton    Mystery, Thriller, Crime, Drama
# 3          Dave Franco                     Romance, Drama
# 4             Mia Goth   Horror, Science Fiction, Fantasy
# ...                ...                                ...
# 5671                                        Comedy, Drama
# 5672                                       Romance, Music
# 5673        Jan Vlasák                              Drama
# 5674     Norbert Mašek                              Drama
# 5675    Carlos Alhinho                              Drama
#
#                                                keywords  \
# 0                 based on novel or book, sequel, novel
# 1     suicide, based on novel or book, competition, ...
# 2                based on novel or book, gambler, macau
# 3     high school, based on novel or book, aunt niec...
# 4     monster, based on novel or book, mad scientist...
# ...                                                 ...
# 5671  based on novel or book, monte carlo, female fr...
# 5672  based on novel or book, musician, journalism, ...
# 5673                             based on novel or book
# 5674                             based on novel or book
# 5675                 based on novel or book, cape verde
#
#                                                overview original_language
# 0     Jenna and Lion's wedding brings about the long...                es
# 1     In a dystopian, alternate-America ruled by a t...                en
# 2     Amid the glittering casinos of Macau, a gamble...                en
# 3     Morgan Grant and her daughter Clara explore wh...                en
# 4     Dr. Victor Frankenstein, a brilliant but egoti...                en
# ...                                                 ...               ...
# 5671  Four women cross paths in Monte Carlo — each, ...                en
# 5672  Journalist Cecilia James is a sucker for a lov...                en
# 5673                                                                   cs
# 5674                                                                   cs
# 5675  Film adaptation of a novel published in 1960 b...                pt
#
# [5676 rows x 21 columns]

# %%
## ====== Exemple: auteurs adaptés ===== ###

auteurs = movies_novel_dataset['author'].value_counts()
print(auteurs[auteurs > 2])
# Out:
# author
# Charles Dickens    54
# Agatha Christie    52
# Stephen King       44
# Georges Simenon    36
# Jules Verne        31
#                    ..
# Milo Urban          3
# T. Svatopluk        3
# Rao Xueman          3
# Ryo Asai            3
# Thomas Hughes       3
# Name: count, Length: 384, dtype: int64

# %%
# ====== Exemples : livres de Stephen King ======= #

hawking_movies = movies_novel_dataset[movies_novel_dataset['author'].str.contains("Stephen King")]
print(hawking_movies[['title', 'year', 'director', 'vote_average']])
# Out:
#                               title  year              director  vote_average
# 1                     The Long Walk  2025      Francis Lawrence         7.000
# 35                   It Chapter Two  2019       Andy Muschietti         6.800
# 37                               It  2017       Andy Muschietti         7.237
# 40         The Shawshank Redemption  1994        Frank Darabont         8.700
# 66                      The Shining  1980       Stanley Kubrick         8.200
# 92                    The Dead Zone  1983      David Cronenberg         7.012
# 96                   The Green Mile  1999        Frank Darabont         8.502
# 97                  The Running Man  2025          Edgar Wright         0.000
# 144                          Carrie  1976        Brian De Palma         7.300
# 151                    Pet Sematary  1989          Mary Lambert         6.635
# 234                          Misery  1990            Rob Reiner         7.745
# 248                          Carrie  2013       Kimberly Peirce         6.000
# 260                        The Mist  2007        Frank Darabont         6.936
# 295                    Pet Sematary  2019        Dennis Widmyer         5.744
# 296                    Dreamcatcher  2003       Lawrence Kasdan         5.630
# 304                    Doctor Sleep  2019         Mike Flanagan         7.143
# 335                   Silver Bullet  1985         Daniel Attias         6.581
# 343                     Stand by Me  1986            Rob Reiner         7.850
# 364                          Carrie  2002          David Carson         6.100
# 387                 The Running Man  1987   Paul Michael Glaser         6.539
# 414                  The Dark Tower  2017         Nikolaj Arcel         5.779
# 442                       Apt Pupil  1998          Bryan Singer         6.512
# 452                            1922  2017          Zak Hilditch         5.934
# 453                     Firestarter  1984        Mark L. Lester         6.252
# 555                     Salem's Lot  2024        Gary Dauberman         6.028
# 599                         Thinner  1996           Tom Holland         5.888
# 606                            Cujo  1983          Lewis Teague         6.142
# 1081              In the Tall Grass  2019       Vincenzo Natali         5.544
# 1284                  Gerald's Game  2017         Mike Flanagan         6.402
# 1442                           Cell  2016          Tod Williams         4.715
# 1604                  The Dark Half  1993      George A. Romero         5.982
# 1724                Julie Ganapathi  2003         Balu Mahendra         7.500
# 2125                 Needful Things  1993  Fraser Clarke Heston         6.200
# 2348                    Desperation  2006           Mick Garris         5.500
# 2358                    Firestarter  2022          Keith Thomas         5.472
# 2592              Dolores Claiborne  1995       Taylor Hackford         7.265
# 4688           The Breathing Method            Scott Derrickson         0.000
# 4694                      The Stand                  Doug Liman         0.000
# 5293                 From a Buick 8          William Brent Bell         0.000
# 5336                  The Dead Zone                                     0.000
# 5486             Untitled Cujo Film                                     0.000
# 5518              Susannah's Lesson  2015        Shahab Zargari         6.000
# 5555  The Girl Who Loved Tom Gordon                  JT Mollner         0.000
# 5560              Susannah's Lesson  2015        Shahab Zargari         6.000

# %%
## ==== SAVE LES DF ==== #

movies_df.to_csv("movies_dataset.csv")
movies_novel_dataset.to_csv("movies_novel_dataset.csv")

# %% [markdown]
# # 2 - Lier les films aux livres

# %%
def google_books_data(df):
    df = df.copy()  

  
    for col in ['isbn', 'publishedDate', 'pageCount', 'averageRating', 'ratingsCount', 'categories', 'language']:
        df[col] = None

    for i, row in tqdm(df.iterrows(), total=len(df), desc="Book"):
        query = f"{row['title']} {row['author']}"
        url = f"https://www.googleapis.com/books/v1/volumes?q={query}"
        response = requests.get(url)
        data = response.json()

        if 'items' in data and len(data['items']) > 0:
            volume = data['items'][0]['volumeInfo']

# %%
hawking_movies_updated = google_books_data(hawking_movies)
# Out:
# Book: 100%|████████████████████████████████████████████████████████████████████████████| 44/44 [00:40<00:00,  1.08it/s]

# %%
print(hawking_movies_updated)
# trop de livres à None niveaux ratings...
# Out:
#       tmdb_id     imdb_id                          title  \
# 1      604079  tt10374610                  The Long Walk
# 35     474350   tt7349950                 It Chapter Two
# 37     346364   tt1396484                             It
# 40        278   tt0111161       The Shawshank Redemption
# 66        694   tt0081505                    The Shining
# 92      11336   tt0085407                  The Dead Zone
# 96        497   tt0120689                 The Green Mile
# 97     798645  tt14107334                The Running Man
# 144      7340   tt0074285                         Carrie
# 151      8913   tt0098084                   Pet Sematary
# 234      1700   tt0100157                         Misery
# 248    133805   tt1939659                         Carrie
# 260      5876   tt0884328                       The Mist
# 295    157433   tt0837563                   Pet Sematary
# 296      6171   tt0285531                   Dreamcatcher
# 304    501170   tt5606664                   Doctor Sleep
# 335     17898   tt0090021                  Silver Bullet
# 343       235   tt0092005                    Stand by Me
# 364      7342   tt0319970                         Carrie
# 387       865   tt0093894                The Running Man
# 414    353491   tt1648190                 The Dark Tower
# 442      9445   tt0118636                      Apt Pupil
# 452    452507   tt6214928                           1922
# 453     11495   tt0087262                    Firestarter
# 555    748230  tt10245072                    Salem's Lot
# 599     10280   tt0117894                        Thinner
# 606     10489   tt0085382                           Cujo
# 1081   523139   tt4687108              In the Tall Grass
# 1284   343674   tt3748172                  Gerald's Game
# 1442   168098   tt0775440                           Cell
# 1604    10349   tt0106664                  The Dark Half
# 1724   257075   tt0353590                Julie Ganapathi
# 2125    10657   tt0107665                 Needful Things
# 2348    10004   tt0129871                    Desperation
# 2358   532710   tt1798632                    Firestarter
# 2592    11929   tt0109642              Dolores Claiborne
# 4688   780605   tt2461894           The Breathing Method
# 4694  1503446  tt37434515                      The Stand
# 5293   618349   tt8753656                 From a Buick 8
# 5336  1249897                              The Dead Zone
# 5486  1446820  tt36144364             Untitled Cujo Film
# 5518  1065646   tt4627542              Susannah's Lesson
# 5555   625121  tt10847802  The Girl Who Loved Tom Gordon
# 5560  1065646   tt4627542              Susannah's Lesson
#
#                      original_title release_date  year  runtime    budget  \
# 1                     The Long Walk   2025-09-10  2025      108  20000000
# 35                   It Chapter Two   2019-09-04  2019      169  79000000
# 37                               It   2017-09-06  2017      135  35000000
# 40         The Shawshank Redemption   1994-09-23  1994      142  25000000
# 66                      The Shining   1980-05-23  1980      144  19000000
# 92                    The Dead Zone   1983-10-21  1983      103  10000000
# 96                   The Green Mile   1999-12-10  1999      189  60000000
# 97                  The Running Man   2025-11-12  2025      133         0
# 144                          Carrie   1976-11-03  1976       98   1800000
# 151                    Pet Sematary   1989-04-21  1989      102  11500000
# 234                          Misery   1990-11-30  1990      107  20000000
# 248                          Carrie   2013-10-16  2013      100  30000000
# 260                        The Mist   2007-11-21  2007      126  18000000
# 295                    Pet Sematary   2019-04-04  2019      100  21000000
# 296                    Dreamcatcher   2003-03-21  2003      136  68000000
# 304                    Doctor Sleep   2019-10-30  2019      152  45000000
# 335                   Silver Bullet   1985-10-10  1985       95   7000000
# 343                     Stand by Me   1986-08-08  1986       89   8000000
# 364                          Carrie   2002-11-04  2002      132   5000000
# 387                 The Running Man   1987-11-13  1987      100  27000000
# 414                  The Dark Tower   2017-08-03  2017       95  60000000
# 442                       Apt Pupil   1998-10-23  1998      107  14000000
# 452                            1922   2017-10-20  2017      102   5000000
# 453                     Firestarter   1984-05-11  1984      115  15000000
# 555                     Salem's Lot   2024-10-03  2024      113         0
# 599                         Thinner   1996-10-25  1996       92   8000000
# 606                            Cujo   1983-08-10  1983       93   5000000
# 1081              In the Tall Grass   2019-09-20  2019      102         0
# 1284                  Gerald's Game   2017-09-29  2017      104         0
# 1442                           Cell   2016-07-06  2016       98         0
# 1604                  The Dark Half   1993-04-23  1993      121  15000000
# 1724                     ஜூலி கணபதி   2003-02-01  2003      141         0
# 2125                 Needful Things   1993-08-27  1993      120         0
# 2348                    Desperation   2006-05-23  2006      131  12000000
# 2358                    Firestarter   2022-05-12  2022       94  12000000
# 2592              Dolores Claiborne   1995-03-24  1995      132  13000000
# 4688           The Breathing Method                           0         0
# 4694                      The Stand                           0         0
# 5293                 From a Buick 8                           0         0
# 5336                  The Dead Zone                           0         0
# 5486             Untitled Cujo Film                           0         0
# 5518              Susannah's Lesson   2015-03-18  2015        9      2000
# 5555  The Girl Who Loved Tom Gordon                           0         0
# 5560              Susannah's Lesson   2015-03-18  2015        9      2000
#
#         revenue  vote_average  ...  \
# 1      54054069         7.000  ...
# 35    473123154         6.800  ...
# 37    704242888         7.237  ...
# 40     28341469         8.700  ...
# 66     44781695         8.200  ...
# 92     20766616         7.012  ...
# 96    286801374         8.502  ...
# 97            0         0.000  ...
# 144    33800000         7.300  ...
# 151    57500000         6.635  ...
# 234    61300000         7.745  ...
# 248    84790678         6.000  ...
# 260    57470220         6.936  ...
# 295   113118226         5.744  ...
# 296    81240206         5.630  ...
# 304    72385286         7.143  ...
# 335    12400000         6.581  ...
# 343    52300000         7.850  ...
# 364           0         6.100  ...
# 387    38122105         6.539  ...
# 414   113231078         5.779  ...
# 442     8863193         6.512  ...
# 452     2943477         5.934  ...
# 453    17080167         6.252  ...
# 555      851156         6.028  ...
# 599    15315484         5.888  ...
# 606    21200000         6.142  ...
# 1081          0         5.544  ...
# 1284          0         6.402  ...
# 1442    1133031         4.715  ...
# 1604   10611160         5.982  ...
# 1724          0         7.500  ...
# 2125   15185672         6.200  ...
# 2348          0         5.500  ...
# 2358   15000000         5.472  ...
# 2592   46400000         7.265  ...
# 4688          0         0.000  ...
# 4694          0         0.000  ...
# 5293          0         0.000  ...
# 5336          0         0.000  ...
# 5486          0         0.000  ...
# 5518          0         6.000  ...
# 5555          0         0.000  ...
# 5560          0         6.000  ...
#
#                                                keywords  \
# 1     suicide, based on novel or book, competition, ...
# 35    based on novel or book, clown, carnival, seque...
# 37    small town, based on novel or book, clown, bul...
# 40    prison, friendship, police brutality, corrupti...
# 66    hotel, new year's eve, child abuse, based on n...
# 92    sheriff, coma, based on novel or book, sacrifi...
# 96    mentally disabled, death penalty, based on nov...
# 97    based on novel or book, survival, on the run, ...
# 144   high school, child abuse, based on novel or bo...
# 151   based on novel or book, funeral, parent child ...
# 234   based on novel or book, nurse, psychopath, col...
# 248   high school, based on novel or book, telekines...
# 260   monster, based on novel or book, supermarket, ...
# 295   husband wife relationship, countryside, based ...
# 296   based on novel or book, 1970s, religion and su...
# 304   based on novel or book, supernatural, haunted ...
# 335             based on novel or book, maine, werewolf
# 343   friendship, based on novel or book, leech, aff...
# 364   puberty, high school, based on novel or book, ...
# 387   based on novel or book, dystopia, game show, o...
# 414   mind control, gunslinger, based on novel or bo...
# 442   high school, based on novel or book, secret id...
# 452   based on novel or book, parent child relations...
# 453   fire, based on novel or book, telepathy, psych...
# 555   based on novel or book, vampire, remake, pries...
# 599   based on novel or book, curse, fat suit, distu...
# 606   based on novel or book, animal attack, cadilla...
# 1081  based on novel or book, maze, pregnant woman, ...
# 1284  child abuse, based on novel or book, childhood...
# 1442  suicide, airport, based on novel or book, bost...
# 1604  new york city, sheriff, based on novel or book...
# 1724  based on novel or book, musical, foreign langu...
# 2125  small town, sheriff, based on novel or book, p...
# 2348  sheriff, based on novel or book, psychopath, n...
# 2358  fire, based on novel or book, telepathy, psych...
# 2592  depression, child abuse, island, based on nove...
# 4688       based on novel or book, based on short story
# 4694    based on novel or book, post-apocalyptic future
# 5293  small town, based on novel or book, pennsylvan...
# 5336  coma, based on novel or book, remake, supernat...
# 5486  based on novel or book, animal attack, remake,...
# 5518  gunslinger, based on novel or book, crowdfunde...
# 5555                             based on novel or book
# 5560  gunslinger, based on novel or book, crowdfunde...
#
#                                                overview original_language  \
# 1     In a dystopian, alternate-America ruled by a t...                en
# 35    27 years after overcoming the malevolent super...                en
# 37    In a small town in Maine, seven children known...                en
# 40    Imprisoned in the 1940s for the double murder ...                en
# 66    Jack Torrance accepts a caretaker job at the O...                en
# 92    Johnny Smith is a schoolteacher with his whole...                en
# 96    A supernatural tale set on death row in a Sout...                en
# 97    Desperate to save his sick daughter, working-c...                en
# 144   Withdrawn and sensitive teenager Carrie White ...                en
# 151   After the Creed family's cat is accidentally k...                en
# 234   After an accident, acclaimed novelist Paul She...                en
# 248   An awkward, telekinetic teenage girl is the ob...                en
# 260   After a violent storm, a dense cloud of mist e...                en
# 295   Dr. Louis Creed and his wife, Rachel, move fro...                en
# 296   Four boyhood pals perform a heroic act and are...                en
# 304   Still scarred by the trauma he endured as a ch...                en
# 335   The small city of Tarker's Mills is startled b...                en
# 343   After learning that a boy their age has been a...                en
# 364   An awkward, telekinetic teenage girl's lonely ...                en
# 387   By 2017, the global economy has collapsed and ...                en
# 414   A boy haunted by visions of a parallel world a...                en
# 442   One day in 1984, Todd Bowden, a brilliant high...                en
# 452   A simple yet proud rancher conspires to murder...                en
# 453   Charlene "Charlie" McGee has the amazing abili...                en
# 555   Author Ben Mears returns to his childhood home...                en
# 599   An obese lawyer finds himself growing "Thinner...                en
# 606   A friendly St. Bernard named "Cujo" contracts ...                en
# 1081  After hearing a child screaming for help from ...                en
# 1284  When her husband's sex game goes wrong, Jessie...                en
# 1442  When a strange signal pulsates through all cel...                en
# 1604  Following the public's realization that Thad B...                en
# 1724  Tenkasi, the creator of a hit television show,...                ta
# 2125  A mysterious new shop opens in a small town wh...                en
# 2348  When a sheriff arrests a writer, a family, a c...                en
# 2358  For more than a decade, parents Andy and Vicky...                en
# 2592  Dolores Claiborne was accused of killing her a...                en
# 4688  Upcoming adaptation of the Stephen King novell...                en
# 4694  A feature adaptation of Stephen King’s ambitio...                en
# 5293  A small Pennsylvania town is plagued by a seri...                en
# 5336  A remake of David Cronenberg's 1983 adaptation...                en
# 5486       Based on the Stephen King bestselling novel.                en
# 5518  Based on Stephen King characters from the Dark...                en
# 5555  12-year-old Trisha McFarland strays from the p...                en
# 5560  Based on Stephen King characters from the Dark...                en
#
#                isbn publishedDate pageCount averageRating ratingsCount  \
# 1     9781668052013          2024       400          None         None
# 35    9781802078978    2023-01-16       138          None         None
# 37    9781982127794    2019-07-30      1168             5            4
# 40    9781982155759    2020-09-29       128          None         None
# 66       2709646048    2013-10-30       448          None         None
# 92    9782709675925    2025-11-05       547          None         None
# 96    9781501160448    2017-06-27       512             5            2
# 97    9782226216274    2010-05-20       230             5            3
# 144   9782808684330    2023-05-05        21          None         None
# 151   9781848940857    2010-03-22       442             4            3
# 234   9781501141249    2016-01-01       432             5            2
# 248   9782808684330    2023-05-05        21          None         None
# 260   9782226216335    2010-05-20       135             5            1
# 295   9781848940857    2010-03-22       442             4            3
# 296      3453441885    2023-06-14         0          None         None
# 304   9782226299864    2013-11-01       523             2            1
# 335            None          1985       118          None         None
# 343   9781438113487          2006       237             3            3
# 364   9782808684330    2023-05-05        21          None         None
# 387   9782226216274    2010-05-20       230             5            3
# 414      1880418622    2004-09-21       908             4           59
# 442   9781529379280    2021-09-09       252          None         None
# 452   9798216230700    2014-11-13       243          None         None
# 453   9781501141201    2016-01-01       576          None         None
# 555   9781848940819    2008-12-11       586           4.5            7
# 599   9781501144523    2016-03-08       352          None         None
# 606      227760027X    1999-10-01      None          None         None
# 1081  9782226445582    2019-09-27        49          None         None
# 1284  9781848940710    2010-03-22       343          None         None
# 1442     2253151637    2007-10-03       533          None         None
# 1604  9781848940901    2010-03-22       520           3.5            2
# 1724  9781317212157    2018-10-03       361          None         None
# 2125  9781501143786    2016-05-03       960             5            3
# 2348  9782226216113    2010-05-20       450          None         None
# 2358  9781501141201    2016-01-01       576          None         None
# 2592  9782226216137    2010-05-20       186          None         None
# 4688     0582402271          1998        55          None         None
# 4694  9781848940833    2008-12-11      1562             5            4
# 5293  9781848941007    2010-03-22       433             1            1
# 5336  9782709675925    2025-11-05       547          None         None
# 5486     0809238187          1991       804             5            1
# 5518  9782017104568    2019-10-02       290          None         None
# 5555  9781848940956    2010-03-22       215          None         None
# 5560  9782017104568    2019-10-02       290          None         None
#
#               categories language
# 1               Contests     None
# 35       Performing Arts     None
# 37               Fiction     None
# 40               Fiction     None
# 66                           None
# 92               Fiction     None
# 96               Fiction     None
# 97               Fiction     None
# 144              Fiction     None
# 151              Fiction     None
# 234              Fiction     None
# 248              Fiction     None
# 260              Fiction     None
# 295              Fiction     None
# 296                          None
# 304              Fiction     None
# 335                          None
# 343            Criticism     None
# 364              Fiction     None
# 387              Fiction     None
# 414              Fiction     None
# 442              Fiction     None
# 452   Literary Criticism     None
# 453              Fiction     None
# 555              Fiction     None
# 599              Fiction     None
# 606                          None
# 1081             Fiction     None
# 1284             Fiction     None
# 1442                         None
# 1604             Fiction     None
# 1724      Social Science     None
# 2125             Fiction     None
# 2348             Fiction     None
# 2358             Fiction     None
# 2592             Fiction     None
# 4688        Horror tales     None
# 4694             Fiction     None
# 5293             Fiction     None
# 5336             Fiction     None
# 5486  Literary Criticism     None
# 5518             Fiction     None
# 5555             Fiction     None
# 5560             Fiction     None
#
# [44 rows x 28 columns]
